# %% [markdown]
# ## EDA

# %% [markdown]
# DATASET SOURCE: https://www.kaggle.com/datasets/sunilthite/llm-detect-ai-generated-text-dataset
#
# In this Dataset contains both AI Generated Essay and Human Written Essay for Training Purpose
# This dataset challenge is to to develop a machine learning model that can accurately detect whether an essay was written by a student or an LLM. The competition dataset comprises a mix of student-written essays and essays generated by a variety of LLMs.
#
# Dataset contains more than 28,000 essay written by student and AI generated.
#
# Features :
#
#     text : Which contains essay text
#
#     generated : This is target label . 0 - Human Written Essay , 1 - AI Generated Essay
#
# From these features for us the only important values will be the texts.

# %%
import pandas as pd
import numpy as np
import random
import os
import re
import torch
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')

# %% [markdown]
# ### Data cleaning
#
# In this step we are cleaning the original text to be suitable for further work. We are making:
#
#     - removing special characters
#     - removing numbers
#     - removing punctations
#     - tokenization
#     - removing stopwords
#     - lemmatization
#
# Then we can see an example from the the original esseys and the cleaned as well.

# %%
# Initialize WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

def clean_text(text_to_clean):
    text_to_clean = text_to_clean.lower()

    # Remove special characters, numbers, and punctuation
    text_to_clean = re.sub(r'[^a-zA-Z\s]', '', text_to_clean)

    # Tokenize text
    tokens = word_tokenize(text_to_clean)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Lemmatize tokens using WordNet
    tokens = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in tokens]

    # Join tokens
    cleaned_text = ' '.join(tokens)
    return cleaned_text

df = pd.read_csv('./datasets/Training_Essay_Data.csv')

# Check if the cleaned text CSV file exists
cleaned_text_file = 'cleaned_text.csv'
if not os.path.exists(cleaned_text_file):
    print("Cleaning dataset")
    df['clean_text'] = df['text'].apply(clean_text)
    df = df[df['clean_text'].str.split().apply(len) > 0]
    df.to_csv(cleaned_text_file, index=False)
    print("Cleaned text saved to:", cleaned_text_file)
else:
    df = pd.read_csv(cleaned_text_file)
    print("Cleaned text loaded from:", cleaned_text_file)
# Out:
# Cleaned text loaded from: cleaned_text.csv

# %%
print("Essey example (not cleaned):")
print(df['text'].iloc[0])
# Out:
# Essey example (not cleaned):
# Car-free cities have become a subject of increasing interest and debate in recent years, as urban areas around the world grapple with the challenges of congestion, pollution, and limited resources. The concept of a car-free city involves creating urban environments where private automobiles are either significantly restricted or completely banned, with a focus on alternative transportation methods and sustainable urban planning. This essay explores the benefits, challenges, and potential solutions associated with the idea of car-free cities.  Benefits of Car-Free Cities  Environmental Sustainability: Car-free cities promote environmental sustainability by reducing air pollution and greenhouse gas emissions. Fewer cars on the road mean cleaner air and a significant decrease in the contribution to global warming.  Improved Public Health: A reduction in automobile usage can lead to better public health outcomes. Fewer cars on the road result in fewer accidents and a safer urban environment for pedestrians and cyclists. Moreover, less air pollution can lead to reduced respiratory and cardiovascular problems.  Efficient Use of Space: Car-free cities utilize urban space more efficiently. Parking lots and wide roads can be repurposed for green spaces, parks, and pedestrian zones, enhancing the overall quality of life in the city.  Reduced Traffic Congestion: By eliminating or restricting car usage, traffic congestion is significantly reduced, leading to faster commute times and less frustration for residents and commuters.  Cost Savings: Car ownership and maintenance can be expensive. Car-free cities allow residents to save money on vehicles, fuel, and insurance, improving their overall financial well-being.  Challenges of Car-Free Cities  Resistance to Change: Transitioning to a car-free city can face resistance from citizens, especially those who rely heavily on their cars for daily activities and commutes.  Public Transportation Infrastructure: An effective public transportation system is crucial for the success of car-free cities. Cities need to invest in and expand their public transportation networks to ensure that people have viable alternatives to cars.  Economic Impact: Businesses that rely on car-dependent customers may experience a decline in revenue in a car-free city. It's essential to address this economic impact and find ways to support affected businesses during the transition.  Urban Planning and Infrastructure: The redesign of urban areas for car-free living requires significant planning and investment in infrastructure, which can be a lengthy and complex process.  Solutions for Car-Free Cities  Expand Public Transportation: Invest in the expansion and improvement of public transportation systems to provide convenient and affordable alternatives to private cars.  Promote Active Transportation: Encourage walking and cycling by building bike lanes, pedestrian-friendly streets, and ensuring safe infrastructure for these activities.  Implement Carpooling and Ride-Sharing: Promote carpooling and ride-sharing services to reduce the number of private vehicles on the road.  Adopt Electric and Sustainable Transportation: Encourage the use of electric vehicles and promote sustainability by using renewable energy sources to power transportation.  Education and Public Awareness: Educate citizens about the benefits of a car-free city and involve them in the planning process to increase support and understanding.  Conclusion  Car-free cities represent a vision for a sustainable and healthier urban future. While the transition to a car-free city is not without challenges, the potential benefits in terms of environmental sustainability, public health, and efficient urban living make it a compelling goal. Through a combination of investment in public transportation, promotion of alternative transportation methods, and public engagement, cities can work towards a future where cars are no longer the dominant mode of transportation. Ca ...

# %%
print("Essey example (cleaned):")
print(df['clean_text'].iloc[0])
# Out:
# Essey example (cleaned):
# carfree city become subject increase interest debate recent year urban area around world grapple challenge congestion pollution limited resource concept carfree city involves create urban environment private automobile either significantly restrict completely ban focus alternative transportation method sustainable urban planning essay explores benefit challenge potential solution associate idea carfree city benefit carfree city environmental sustainability carfree city promote environmental sustainability reduce air pollution greenhouse gas emission few car road mean cleaner air significant decrease contribution global warm improve public health reduction automobile usage lead well public health outcome few car road result few accident safer urban environment pedestrian cyclist moreover less air pollution lead reduce respiratory cardiovascular problem efficient use space carfree city utilize urban space efficiently parking lot wide road repurposed green space park pedestrian zone enhance overall quality life city reduce traffic congestion eliminate restrict car usage traffic congestion significantly reduce lead faster commute time less frustration resident commuter cost saving car ownership maintenance expensive carfree city allow resident save money vehicle fuel insurance improve overall financial wellbeing challenge carfree city resistance change transition carfree city face resistance citizen especially rely heavily car daily activity commute public transportation infrastructure effective public transportation system crucial success carfree city city need invest expand public transportation network ensure people viable alternative car economic impact business rely cardependent customer may experience decline revenue carfree city essential address economic impact find way support affected business transition urban planning infrastructure redesign urban area carfree living require significant planning investment infrastructure lengthy complex process solution carfree city expand public transportation invest expansion improvement public transportation system provide convenient affordable alternative private car promote active transportation encourage walk cycling building bike lane pedestrianfriendly street ensure safe infrastructure activity implement carpooling ridesharing promote carpooling ridesharing service reduce number private vehicle road adopt electric sustainable transportation encourage use electric vehicle promote sustainability use renewable energy source power transportation education public awareness educate citizen benefit carfree city involve planning process increase support understand conclusion carfree city represent vision sustainable healthier urban future transition carfree city without challenge potential benefit term environmental sustainability public health efficient urban living make compelling goal combination investment public transportation promotion alternative transportation method public engagement city work towards future car longer dominant mode transportation carfree city offer promising vision sustainable vibrant urban environment

# %% [markdown]
# ### Creating vocabulary
#
# In this step we are using a tokenizer to get the vocabulary of these all esseys.

# %%
# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['clean_text'])
vocab_size = len(tokenizer.word_index) + 1

# Save the vocabulary, if does not exist
file_path = 'tokenizer_vocab_with_frequency_embedding.csv'
file_path3 = 'embedding_matrix.npy'
if not os.path.exists(file_path):
    word_index = tokenizer.word_index
    word_counts = tokenizer.word_counts
    word_index_df = pd.DataFrame(word_index.items(), columns=['Word', 'Index'])
    word_counts_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Frequency'])
    tokenizer_vocab_df = pd.merge(word_index_df, word_counts_df, on='Word', how='left')
    tokenizer_vocab_df = tokenizer_vocab_df.sort_values(by='Frequency', ascending=False)
    tokenizer_vocab_df = tokenizer_vocab_df[['Word', 'Index', 'Frequency']]
    tokenizer_vocab_df = tokenizer_vocab_df[tokenizer_vocab_df['Frequency'] >= 20]

    # Load pre-trained GloVe embeddings
    embeddings_index = {}
    embedding_dim = 50
    glove_file = 'glove.6B.50d.txt'

    with open(glove_file, encoding='utf-8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs

    # "Unknown" token and initialization of embedding vector
    unknown_token = '<UNK>'
    unknown_vector = np.zeros(embedding_dim)
    word_count = 0

    # Update the vocabulary based on GloVe embeddings
    for index, row in tokenizer_vocab_df.iterrows():
        word = row['Word']

        # Change token to <UNK> for words not in GloVe
        if word not in embeddings_index:
            tokenizer_vocab_df.at[index, 'Word'] = unknown_token
        else:
            unknown_vector += embeddings_index[word]
            word_count += 1

    # Calculate average for unknown vector 
    unknown_vector = np.divide(unknown_vector, word_count)

    # Remove duplicates and reset indices of the vocabulary DataFrame
    tokenizer_vocab_df = tokenizer_vocab_df.drop_duplicates(subset='Word').reset_index(drop=True)

    # Add missing word to tokenizer
    missing_token = '<MISSING>'
    row_miss = [missing_token, 0, 0]
    tokenizer_vocab_df 
    tokenizer_vocab_df = pd.concat([pd.DataFrame([row_miss], columns=tokenizer_vocab_df.columns), tokenizer_vocab_df], ignore_index=True)

    # Create embedding matrix, do not change vocab after this step!!!
    new_vocab_size = tokenizer_vocab_df.shape[0]
    embedding_matrix = np.zeros((new_vocab_size, embedding_dim))
    print(embedding_matrix.shape)

    for index, row in tokenizer_vocab_df.iterrows():
        word = row['Word']
        # Set index to index in vocab
        tokenizer_vocab_df.at[index, 'Index'] = index

        if(word == unknown_token):
            embedding_matrix[index] = unknown_vector
        elif(word == missing_token):
            embedding_matrix[index] = np.zeros(embedding_dim)
        else: 
            embedding_matrix[index] = embeddings_index[word]
    
    tokenizer_vocab_df.to_csv(file_path, index=False)
    np.save(file_path3, embedding_matrix)
    print("Vocabulary saved")
else:
    tokenizer_vocab_df = pd.read_csv(file_path)
    print("Vocabulary loaded")
# Out:
# Vocabulary loaded

# %%
tokenizer_vocab_df
# Out:
#            Word  Index  Frequency
# 0     <MISSING>      0          0
# 1        people      1      85061
# 2           car      2      68145
# 3          make      3      51179
# 4          vote      4      45807
# ...         ...    ...        ...
# 7048       spit   7048         20
# 7049    coexist   7049         20
# 7050    lawsuit   7050         20
# 7051       boss   7051         20
# 7052   contries   7052         20
#
# [7053 rows x 3 columns]

# %% [markdown]
# ### Handling missing words
#
# In this part we are creating esseys with marked missing words like we are choosing 1 to 4 random words in the text and adding a mark.
#
# missing_word -> \*missing_word\* (to označenie sme na konci nepotrebovali, lebo sme generovali number representation s pomocou position_index_pairs)
#
# We are creating position_index_pairs_all as well, which are representing each esseys missing words the position in the text and the representation index according to the vocabulary.
#
# Then we are saving these new esseys in training_examples, and position_index_pairs_all as well.

# %%
def create_missing_word_examples(text, tokenizer_vocab_df, min_missing_words=1, max_missing_words=1, max_essay_length=50):
    words = text.split()[:max_essay_length]
    if len(words) <= max_missing_words + 2:
        return 0

    missing_word_examples = []
    words_with_marks = words.copy()
    position_index_pairs = []

    while len(missing_word_examples) < 1:
        num_missing_words = random.randint(min_missing_words, max_missing_words)
        missing_word_indices = random.sample(range(1, len(words) - 1), num_missing_words)

        for index in missing_word_indices:
            # Choose a random word until it's in the vocabulary
            try_choice = 0
            while True:
                missing_word = words[index]
                index_in_vocab = tokenizer_vocab_df[tokenizer_vocab_df['Word'] == missing_word]['Index'].values
                if len(index_in_vocab) > 0:
                    break

                # Choose another random word
                missing_word = random.choice(list(tokenizer_vocab_df['Word']))
                index_in_vocab = tokenizer_vocab_df[tokenizer_vocab_df['Word'] == missing_word]['Index'].values
                words[index] = missing_word
                try_choice += 1

            words_with_marks[index] = missing_word  # '*' + missing_word + '*'
            # Position missing word pairs
            position = index
            position_index_pairs.append((position, index_in_vocab[0]))

        input_text = ' '.join(words_with_marks)  # Join the words with marks back into a string
        output_word_indices = [tokenizer_vocab_df[tokenizer_vocab_df['Word'] == words[index]]['Index'].values[0] for index in missing_word_indices]
        missing_word_examples.append(input_text)

    position_index_pairs_all.append(position_index_pairs)
    # print(position_index_pairs)

    return missing_word_examples


# Handling Missing Words
position_index_pairs_all = []

# Creating Training Examples
training_examples = []
k = 0
for text in df['clean_text']:
    examples = create_missing_word_examples(text, tokenizer_vocab_df)
    if examples == 0:
        continue
    training_examples.extend(examples)
    print(f"Example {k} created")
    k += 1

# Convert position_index_pairs to a NumPy array
file_path2 = 'position_index_pairs.npy'
position_index_pairs_array = np.array(position_index_pairs_all, dtype=object)
np.save(file_path2, position_index_pairs_array)
# Out:
# Example 0 created
# Example 1 created
# Example 2 created
# Example 3 created
# Example 4 created
# Example 5 created
# Example 6 created
# Example 7 created
# Example 8 created
# Example 9 created
# Example 10 created
# Example 11 created
# Example 12 created
# Example 13 created
# Example 14 created
# Example 15 created
# Example 16 created
# Example 17 created
# Example 18 created
# Example 19 created
# Example 20 created
# Example 21 created
# Example 22 created
# Example 23 created
# Example 24 created
# Example 25 created
# Example 26 created
# Example 27 created
# Example 28 created
# Example 29 created
# Example 30 created
# Example 31 created
# Example 32 created
# Example 33 created
# Example 34 created
# Example 35 created
# Example 36 created
# Example 37 created
# Example 38 created
# Example 39 created
# Example 40 created
# Example 41 created
# Example 42 created
# Example 43 created
# Example 44 created
# Example 45 created
# Example 46 created
# Example 47 created
# Example 48 created
# Example 49 created
# Example 50 created
# Example 51 created
# Example 52 created
# Example 53 created
# Example 54 created
# Example 55 created
# Example 56 created
# Example 57 created
# Example 58 created
# Example 59 created
# Example 60 created
# Example 61 created
# Example 62 created
# Example 63 created
# Example 64 created
# Example 65 created
# Example 66 created
# Example 67 created
# Example 68 created
# Example 69 created
# Example 70 created
# Example 71 created
# Example 72 created
# Example 73 created
# Example 74 created
# Example 75 created
# Example 76 created
# Example 77 created
# Example 78 created
# Example 79 created
# Example 80 created
# Example 81 created
# Example 82 created
# Example 83 created
# Example 84 created
# Example 85 created
# Example 86 created
# Example 87 created
# Example 88 created
# Example 89 created
# Example 90 created
# Example 91 created
# Example 92 created
# Example 93 created
# Example 94 created
# Example 95 created
# Example 96 created
# Example 97 created
# Example 98 created
# Example 99 created
# Example 100 created
# Example 101 created
# Example 102 created
# Example 103 created
# Example 104 created
# Example 105 created
# Example 106 created
# Example 107 created
# Example 108 created
# Example 109 created
# Example 110 created
# Example 111 created
# Example 112 created
# Example 113 created
# Example 114 created
# Example 115 created
# Example 116 created
# Example 117 created
# Example 118 created
# Example 119 created
# Example 120 created
# Example 121 created
# Example 122 created
# Example 123 created
# Example 124 created
# Example 125 created
# Example 126 created
# Example 127 created
# Example 128 created
# Example 129 created
# Example 130 created
# Example 131 created
# Example 132 created
# Example 133 created
# Example 134 created
# Example 135 created
# Example 136 created
# Example 137 created
# Example 138 created
# Example 139 created
# Example 140 created
# Example 141 created
# Example 142 created
# Example 143 created
# Example 144 created
# Example 145 created
# Example 146 created
# Example 147 created
# Example 148 created
# Example 149 created
# Example 150 created
# Example 151 created
# Example 152 created
# Example 153 created
# Example 154 created
# Example 155 created
# Example 156 created
# Example 157 created
# Example 158 created
# Example 159 created
# Example 160 created
# Example 161 created
# Example 162 created
# Example 163 created
# Example 164 created
# Example 165 created
# Example 166 created
# Example 167 created
# Example 168 created
# Example 169 created
# Example 170 created
# Example 171 created
# Example 172 created
# Example 173 created
# Example 174 created
# Example 175 created
# Example 176 created
# Example 177 created
# Example 178 created
# Example 179 created
# Example 180 created
# Example 181 created
# Example 182 created
# Example 183 created
# Example 184 created
# Example 185 created
# Example 186 created
# Example 187 created
# Example 188 created
# Example 189 created
# Example 190 created
# Example 191 created
# Example 192 created
# Example 193 created
# Example 194 created
# Example 195 created
# Example 196 created
# Example 197 created
# Example 198 created
# Example 199 created
# Example 200 created
# Example 201 created
# Example 202 created
# Example 203 created
# Example 204 created
# Example 205 created
# Example 206 created
# Example 207 created
# Example 208 created
# Example 209 created
# Example 210 created
# Example 211 created
# Example 212 created
# Example 213 created
# Example 214 created
# Example 215 created
# Example 216 created
# Example 217 created
# Example 218 created
# Example 219 created
# Example 220 created
# Example 221 created
# Example 222 created
# Example 223 created
# Example 224 created
# Example 225 created
# Example 226 created
# Example 227 created
# Example 228 created
# Example 229 created
# Example 230 created
# Example 231 created
# Example 232 created
# Example 233 created
# Example 234 created
# Example 235 created
# Example 236 created
# Example 237 created
# Example 238 created
# Example 239 created
# Example 240 created
# Example 241 created
# Example 242 created
# Example 243 created
# Example 244 created
# Example 245 created
# Example 246 created
# Example 247 created
# Example 248 created
# Example 249 created
# Example 250 created
# Example 251 created
# Example 252 created
# Example 253 created
# Example 254 created
# Example 255 created
# Example 256 created
# Example 257 created
# Example 258 created
# Example 259 created
# Example 260 created
# Example 261 created
# Example 262 created
# Example 263 created
# Example 264 created
# Example 265 created
# Example 266 created
# Example 267 created
# Example 268 created
# Example 269 created
# Example 270 created
# Example 271 created
# Example 272 created
# Example 273 created
# Example 274 created
# Example 275 created
# Example 276 created
# Example 277 created
# Example 278 created
# Example 279 created
# Example 280 created
# Example 281 created
# Example 282 created
# Example 283 created
# Example 284 created
# Example 285 created
# Example 286 created
# Example 287 created
# Example 288 created
# Example 289 created
# Example 290 created
# Example 291 created
# Example 292 created
# Example 293 created
# Example 294 created
# Example 295 created
# Example 296 created
# Example 297 created
# Example 298 created
# Example 299 created
# Example 300 created
# Example 301 created
# Example 302 created
# Example 303 created
# Example 304 created
# Example 305 created
# Example 306 created
# Example 307 created
# Example 308 created
# Example 309 created
# Example 310 created
# Example 311 created
# Example 312 created
# Example 313 created
# Example 314 created
# Example 315 created
# Example 316 created
# Example 317 created
# Example 318 created
# Example 319 created
# Example 320 created
# Example 321 created
# Example 322 created
# Example 323 created
# Example 324 created
# Example 325 created
# Example 326 created
# Example 327 created
# Example 328 created
# Example 329 created
# Example 330 created
# Example 331 created
# Example 332 created
# Example 333 created
# Example 334 created
# Example 335 created
# Example 336 created
# Example 337 created
# Example 338 created
# Example 339 created
# Example 340 created
# Example 341 created
# Example 342 created
# Example 343 created
# Example 344 created
# Example 345 created
# Example 346 created
# Example 347 created
# Example 348 created
# Example 349 created
# Example 350 created
# Example 351 created
# Example 352 created
# Example 353 created
# Example 354 created
# Example 355 created
# Example 356 created
# Example 357 created
# Example 358 created
# Example 359 created
# Example 360 created
# Example 361 created
# Example 362 created
# Example 363 created
# Example 364 created
# Example 365 created
# Example 366 created
# Example 367 created
# Example 368 created
# Example 369 created
# Example 370 created
# Example 371 created
# Example 372 created
# Example 373 created
# Example 374 created
# Example 375 created
# Example 376 created
# Example 377 created
# Example 378 created
# Example 379 created
# Example 380 created
# Example 381 created
# Example 382 created
# Example 383 created
# Example 384 created
# Example 385 created
# Example 386 created
# Example 387 created
# Example 388 created
# Example 389 created
# Example 390 created
# Example 391 created
# Example 392 created
# Example 393 created
# Example 394 created
# Example 395 created
# Example 396 created
# Example 397 created
# Example 398 created
# Example 399 created
# Example 400 created
# Example 401 created
# Example 402 created
# Example 403 created
# Example 404 created
# Example 405 created
# Example 406 created
# Example 407 created
# Example 408 created
# Example 409 created
# Example 410 created
# Example 411 created
# Example 412 created
# Example 413 created
# Example 414 created
# Example 415 created
# Example 416 created
# Example 417 created
# Example 418 created
# Example 419 created
# Example 420 created
# Example 421 created
# Example 422 created
# Example 423 created
# Example 424 created
# Example 425 created
# Example 426 created
# Example 427 created
# Example 428 created
# Example 429 created
# Example 430 created
# Example 431 created
# Example 432 created
# Example 433 created
# Example 434 created
# Example 435 created
# Example 436 created
# Example 437 created
# Example 438 created
# Example 439 created
# Example 440 created
# Example 441 created
# Example 442 created
# Example 443 created
# Example 444 created
# Example 445 created
# Example 446 created
# Example 447 created
# Example 448 created
# Example 449 created
# Example 450 created
# Example 451 created
# Example 452 created
# Example 453 created
# Example 454 created
# Example 455 created
# Example 456 created
# Example 457 created
# Example 458 created
# Example 459 created
# Example 460 created
# Example 461 created
# Example 462 created
# Example 463 created
# Example 464 created
# Example 465 created
# Example 466 created
# Example 467 created
# Example 468 created
# Example 469 created
# Example 470 created
# Example 471 created
# Example 472 created
# Example 473 created
# Example 474 created
# Example 475 created
# Example 476 created
# Example 477 created
# Example 478 created
# Example 479 created
# Example 480 created
# Example 481 created
# Example 482 created
# Example 483 created
# Example 484 created
# Example 485 created
# Example 486 created
# Example 487 created
# Example 488 created
# Example 489 created
# Example 490 created
# Example 491 created
# Example 492 created
# Example 493 created
# Example 494 created
# Example 495 created
# Example 496 created
# Example 497 created
# Example 498 created
# Example 499 created
# Example 500 created
# Example 501 created
# Example 502 created
# Example 503 created
# Example 504 created
# Example 505 created
# Example 506 created
# Example 507 created
# Example 508 created
# Example 509 created
# Example 510 created
# Example 511 created
# Example 512 created
# Example 513 created
# Example 514 created
# Example 515 created
# Example 516 created
# Example 517 created
# Example 518 created
# Example 519 created
# Example 520 created
# Example 521 created
# Example 522 created
# Example 523 created
# Example 524 created
# Example 525 created
# Example 526 created
# Example 527 created
# Example 528 created
# Example 529 created
# Example 530 created
# Example 531 created
# Example 532 created
# Example 533 created
# Example 534 created
# Example 535 created
# Example 536 created
# Example 537 created
# Example 538 created
# Example 539 created
# Example 540 created
# Example 541 created
# Example 542 created
# Example 543 created
# Example 544 created
# Example 545 created
# Example 546 created
# Example 547 created
# Example 548 created
# Example 549 created
# Example 550 created
# Example 551 created
# Example 552 created
# Example 553 created
# Example 554 created
# Example 555 created
# Example 556 created
# Example 557 created
# Example 558 created
# Example 559 created
# Example 560 created
# Example 561 created
# Example 562 created
# Example 563 created
# Example 564 created
# Example 565 created
# Example 566 created
# Example 567 created
# Example 568 created
# Example 569 created
# Example 570 created
# Example 571 created
# Example 572 created
# Example 573 created
# Example 574 created
# Example 575 created
# Example 576 created
# Example 577 created
# Example 578 created
# Example 579 created
# Example 580 created
# Example 581 created
# Example 582 created
# Example 583 created
# Example 584 created
# Example 585 created
# Example 586 created
# Example 587 created
# Example 588 created
# Example 589 created
# Example 590 created
# Example 591 created
# Example 592 created
# Example 593 created
# Example 594 created
# Example 595 created
# Example 596 created
# Example 597 created
# Example 598 created
# Example 599 created
# Example 600 created
# Example 601 created
# Example 602 created
# Example 603 created
# Example 604 created
# Example 605 created
# Example 606 created
# Example 607 created
# Example 608 created
# Example 609 created
# Example 610 created
# Example 611 created
# Example 612 created
# Example 613 created
# Example 614 created
# Example 615 created
# Example 616 created
# Example 617 created
# Example 618 created
# Example 619 created
# Example 620 created
# Example 621 created
# Example 622 created
# Example 623 created
# Example 624 created
# Example 625 created
# Example 626 created
# Example 627 created
# Example 628 created
# Example 629 created
# Example 630 created
# Example 631 created
# Example 632 created
# Example 633 created
# Example 634 created
# Example 635 created
# Example 636 created
# Example 637 created
# Example 638 created
# Example 639 created
# Example 640 created
# Example 641 created
# Example 642 created
# Example 643 created
# Example 644 created
# Example 645 created
# Example 646 created
# Example 647 created
# Example 648 created
# Example 649 created
# Example 650 created
# Example 651 created
# Example 652 created
# Example 653 created
# Example 654 created
# Example 655 created
# Example 656 created
# Example 657 created
# Example 658 created
# Example 659 created
# Example 660 created
# Example 661 created
# Example 662 created
# Example 663 created
# Example 664 created
# Example 665 created
# Example 666 created
# Example 667 created
# Example 668 created
# Example 669 created
# Example 670 created
# Example 671 created
# Example 672 created
# Example 673 created
# Example 674 created
# Example 675 created
# Example 676 created
# Example 677 created
# Example 678 created
# Example 679 created
# Example 680 created
# Example 681 created
# Example 682 created
# Example 683 created
# Example 684 created
# Example 685 created
# Example 686 created
# Example 687 created
# Example 688 created
# Example 689 created
# Example 690 created
# Example 691 created
# Example 692 created
# Example 693 created
# Example 694 created
# Example 695 created
# Example 696 created
# Example 697 created
# Example 698 created
# Example 699 created
# Example 700 created
# Example 701 created
# Example 702 created
# Example 703 created
# Example 704 created
# Example 705 created
# Example 706 created
# Example 707 created
# Example 708 created
# Example 709 created
# Example 710 created
# Example 711 created
# Example 712 created
# Example 713 created
# Example 714 created
# Example 715 created
# Example 716 created
# Example 717 created
# Example 718 created
# Example 719 created
# Example 720 created
# Example 721 created
# Example 722 created
# Example 723 created
# Example 724 created
# Example 725 created
# Example 726 created
# Example 727 created
# Example 728 created
# Example 729 created
# Example 730 created
# Example 731 created
# Example 732 created
# Example 733 created
# Example 734 created
# Example 735 created
# Example 736 created
# Example 737 created
# Example 738 created
# Example 739 created
# Example 740 created
# Example 741 created
# Example 742 created
# Example 743 created
# Example 744 created
# Example 745 created
# Example 746 created
# Example 747 created
# Example 748 created
# Example 749 created
# Example 750 created
# Example 751 created
# Example 752 created
# Example 753 created
# Example 754 created
# Example 755 created
# Example 756 created
# Example 757 created
# Example 758 created
# Example 759 created
# Example 760 created
# Example 761 created
# Example 762 created
# Example 763 created
# Example 764 created
# Example 765 created
# Example 766 created
# Example 767 created
# Example 768 created
# Example 769 created
# Example 770 created
# Example 771 created
# Example 772 created
# Example 773 created
# Example 774 created
# Example 775 created
# Example 776 created
# Example 777 created
# Example 778 created
# Example 779 created
# Example 780 created
# Example 781 created
# Example 782 created
# Example 783 created
# Example 784 created
# Example 785 created
# Example 786 created
# Example 787 created
# Example 788 created
# Example 789 created
# Example 790 created
# Example 791 created
# Example 792 created
# Example 793 created
# Example 794 created
# Example 795 created
# Example 796 created
# Example 797 created
# Example 798 created
# Example 799 created
# Example 800 created
# Example 801 created
# Example 802 created
# Example 803 created
# Example 804 created
# Example 805 created
# Example 806 created
# Example 807 created
# Example 808 created
# Example 809 created
# Example 810 created
# Example 811 created
# Example 812 created
# Example 813 created
# Example 814 created
# Example 815 created
# Example 816 created
# Example 817 created
# Example 818 created
# Example 819 created
# Example 820 created
# Example 821 created
# Example 822 created
# Example 823 created
# Example 824 created
# Example 825 created
# Example 826 created
# Example 827 created
# Example 828 created
# Example 829 created
# Example 830 created
# Example 831 created
# Example 832 created
# Example 833 created
# Example 834 created
# Example 835 created
# Example 836 created
# Example 837 created
# Example 838 created
# Example 839 created
# Example 840 created
# Example 841 created
# Example 842 created
# Example 843 created
# Example 844 created
# Example 845 created
# Example 846 created
# Example 847 created
# Example 848 created
# Example 849 created
# Example 850 created
# Example 851 created
# Example 852 created
# Example 853 created
# Example 854 created
# Example 855 created
# Example 856 created
# Example 857 created
# Example 858 created
# Example 859 created
# Example 860 created
# Example 861 created
# Example 862 created
# Example 863 created
# Example 864 created
# Example 865 created
# Example 866 created
# Example 867 created
# Example 868 created
# Example 869 created
# Example 870 created
# Example 871 created
# Example 872 created
# Example 873 created
# Example 874 created
# Example 875 created
# Example 876 created
# Example 877 created
# Example 878 created
# Example 879 created
# Example 880 created
# Example 881 created
# Example 882 created
# Example 883 created
# Example 884 created
# Example 885 created
# Example 886 created
# Example 887 created
# Example 888 created
# Example 889 created
# Example 890 created
# Example 891 created
# Example 892 created
# Example 893 created
# Example 894 created
# Example 895 created
# Example 896 created
# Example 897 created
# Example 898 created
# Example 899 created
# Example 900 created
# Example 901 created
# Example 902 created
# Example 903 created
# Example 904 created
# Example 905 created
# Example 906 created
# Example 907 created
# Example 908 created
# Example 909 created
# Example 910 created
# Example 911 created
# Example 912 created
# Example 913 created
# Example 914 created
# Example 915 created
# Example 916 created
# Example 917 created
# Example 918 created
# Example 919 created
# Example 920 created
# Example 921 created
# Example 922 created
# Example 923 created
# Example 924 created
# Example 925 created
# Example 926 created
# Example 927 created
# Example 928 created
# Example 929 created
# Example 930 created
# Example 931 created
# Example 932 created
# Example 933 created
# Example 934 created
# Example 935 created
# Example 936 created
# Example 937 created
# Example 938 created
# Example 939 created
# Example 940 created
# Example 941 created
# Example 942 created
# Example 943 created
# Example 944 created
# Example 945 created
# Example 946 created
# Example 947 created
# Example 948 created
# Example 949 created
# Example 950 created
# Example 951 created
# Example 952 created
# Example 953 created
# Example 954 created
# Example 955 created
# Example 956 created
# Example 957 created
# Example 958 created
# Example 959 created
# Example 960 created
# Example 961 created
# Example 962 created
# Example 963 created
# Example 964 created
# Example 965 created
# Example 966 created
# Example 967 created
# Example 968 created
# Example 969 created
# Example 970 created
# Example 971 created
# Example 972 created
# Example 973 created
# Example 974 created
# Example 975 created
# Example 976 created
# Example 977 created
# Example 978 created
# Example 979 created
# Example 980 created
# Example 981 created
# Example 982 created
# Example 983 created
# Example 984 created
# Example 985 created
# Example 986 created
# Example 987 created
# Example 988 created
# Example 989 created
# Example 990 created
# Example 991 created
# Example 992 created
# Example 993 created
# Example 994 created
# Example 995 created
# Example 996 created
# Example 997 created
# Example 998 created
# Example 999 created
# Example 1000 created
# Example 1001 created
# Example 1002 created
# Example 1003 created
# Example 1004 created
# Example 1005 created
# Example 1006 created
# Example 1007 created
# Example 1008 created
# Example 1009 created
# Example 1010 created
# Example 1011 created
# Example 1012 created
# Example 1013 created
# Example 1014 created
# Example 1015 created
# Example 1016 created
# Example 1017 created
# Example 1018 created
# Example 1019 created
# Example 1020 created
# Example 1021 created
# Example 1022 created
# Example 1023 created
# Example 1024 created
# Example 1025 created
# Example 1026 created
# Example 1027 created
# Example 1028 created
# Example 1029 created
# Example 1030 created
# Example 1031 created
# Example 1032 created
# Example 1033 created
# Example 1034 created
# Example 1035 created
# Example 1036 created
# Example 1037 created
# Example 1038 created
# Example 1039 created
# Example 1040 created
# Example 1041 created
# Example 1042 created
# Example 1043 created
# Example 1044 created
# Example 1045 created
# Example 1046 created
# Example 1047 created
# Example 1048 created
# Example 1049 created
# Example 1050 created
# Example 1051 created
# Example 1052 created
# Example 1053 created
# Example 1054 created
# Example 1055 created
# Example 1056 created
# Example 1057 created
# Example 1058 created
# Example 1059 created
# Example 1060 created
# Example 1061 created
# Example 1062 created
# Example 1063 created
# Example 1064 created
# Example 1065 created
# Example 1066 created
# Example 1067 created
# Example 1068 created
# Example 1069 created
# Example 1070 created
# Example 1071 created
# Example 1072 created
# Example 1073 created
# Example 1074 created
# Example 1075 created
# Example 1076 created
# Example 1077 created
# Example 1078 created
# Example 1079 created
# Example 1080 created
# Example 1081 created
# Example 1082 created
# Example 1083 created
# Example 1084 created
# Example 1085 created
# Example 1086 created
# Example 1087 created
# Example 1088 created
# Example 1089 created
# Example 1090 created
# Example 1091 created
# Example 1092 created
# Example 1093 created
# Example 1094 created
# Example 1095 created
# Example 1096 created
# Example 1097 created
# Example 1098 created
# Example 1099 created
# Example 1100 created
# Example 1101 created
# Example 1102 created
# Example 1103 created
# Example 1104 created
# Example 1105 created
# Example 1106 created
# Example 1107 created
# Example 1108 created
# Example 1109 created
# Example 1110 created
# Example 1111 created
# Example 1112 created
# Example 1113 created
# Example 1114 created
# Example 1115 created
# Example 1116 created
# Example 1117 created
# Example 1118 created
# Example 1119 created
# Example 1120 created
# Example 1121 created
# Example 1122 created
# Example 1123 created
# Example 1124 created
# Example 1125 created
# Example 1126 created
# Example 1127 created
# Example 1128 created
# Example 1129 created
# Example 1130 created
# Example 1131 created
# Example 1132 created
# Example 1133 created
# Example 1134 created
# Example 1135 created
# Example 1136 created
# Example 1137 created
# Example 1138 created
# Example 1139 created
# Example 1140 created
# Example 1141 created
# Example 1142 created
# Example 1143 created
# Example 1144 created
# Example 1145 created
# Example 1146 created
# Example 1147 created
# Example 1148 created
# Example 1149 created
# Example 1150 created
# Example 1151 created
# Example 1152 created
# Example 1153 created
# Example 1154 created
# Example 1155 created
# Example 1156 created
# Example 1157 created
# Example 1158 created
# Example 1159 created
# Example 1160 created
# Example 1161 created
# Example 1162 created
# Example 1163 created
# Example 1164 created
# Example 1165 created
# Example 1166 created
# Example 1167 created
# Example 1168 created
# Example 1169 created
# Example 1170 created
# Example 1171 created
# Example 1172 created
# Example 1173 created
# Example 1174 created
# Example 1175 created
# Example 1176 created
# Example 1177 created
# Example 1178 created
# Example 1179 created
# Example 1180 created
# Example 1181 created
# Example 1182 created
# Example 1183 created
# Example 1184 created
# Example 1185 created
# Example 1186 created
# Example 1187 created
# Example 1188 created
# Example 1189 created
# Example 1190 created
# Example 1191 created
# Example 1192 created
# Example 1193 created
# Example 1194 created
# Example 1195 created
# Example 1196 created
# Example 1197 created
# Example 1198 created
# Example 1199 created
# Example 1200 created
# Example 1201 created
# Example 1202 created
# Example 1203 created
# Example 1204 created
# Example 1205 created
# Example 1206 created
# Example 1207 created
# Example 1208 created
# Example 1209 created
# Example 1210 created
# Example 1211 created
# Example 1212 created
# Example 1213 created
# Example 1214 created
# Example 1215 created
# Example 1216 created
# Example 1217 created
# Example 1218 created
# Example 1219 created
# Example 1220 created
# Example 1221 created
# Example 1222 created
# Example 1223 created
# Example 1224 created
# Example 1225 created
# Example 1226 created
# Example 1227 created
# Example 1228 created
# Example 1229 created
# Example 1230 created
# Example 1231 created
# Example 1232 created
# Example 1233 created
# Example 1234 created
# Example 1235 created
# Example 1236 created
# Example 1237 created
# Example 1238 created
# Example 1239 created
# Example 1240 created
# Example 1241 created
# Example 1242 created
# Example 1243 created
# Example 1244 created
# Example 1245 created
# Example 1246 created
# Example 1247 created
# Example 1248 created
# Example 1249 created
# Example 1250 created
# Example 1251 created
# Example 1252 created
# Example 1253 created
# Example 1254 created
# Example 1255 created
# Example 1256 created
# Example 1257 created
# Example 1258 created
# Example 1259 created
# Example 1260 created
# Example 1261 created
# Example 1262 created
# Example 1263 created
# Example 1264 created
# Example 1265 created
# Example 1266 created
# Example 1267 created
# Example 1268 created
# Example 1269 created
# Example 1270 created
# Example 1271 created
# Example 1272 created
# Example 1273 created
# Example 1274 created
# Example 1275 created
# Example 1276 created
# Example 1277 created
# Example 1278 created
# Example 1279 created
# Example 1280 created
# Example 1281 created
# Example 1282 created
# Example 1283 created
# Example 1284 created
# Example 1285 created
# Example 1286 created
# Example 1287 created
# Example 1288 created
# Example 1289 created
# Example 1290 created
# Example 1291 created
# Example 1292 created
# Example 1293 created
# Example 1294 created
# Example 1295 created
# Example 1296 created
# Example 1297 created
# Example 1298 created
# Example 1299 created
# Example 1300 created
# Example 1301 created
# Example 1302 created
# Example 1303 created
# Example 1304 created
# Example 1305 created
# Example 1306 created
# Example 1307 created
# Example 1308 created
# Example 1309 created
# Example 1310 created
# Example 1311 created
# Example 1312 created
# Example 1313 created
# Example 1314 created
# Example 1315 created
# Example 1316 created
# Example 1317 created
# Example 1318 created
# Example 1319 created
# Example 1320 created
# Example 1321 created
# Example 1322 created
# Example 1323 created
# Example 1324 created
# Example 1325 created
# Example 1326 created
# Example 1327 created
# Example 1328 created
# Example 1329 created
# Example 1330 created
# Example 1331 created
# Example 1332 created
# Example 1333 created
# Example 1334 created
# Example 1335 created
# Example 1336 created
# Example 1337 created
# Example 1338 created
# Example 1339 created
# Example 1340 created
# Example 1341 created
# Example 1342 created
# Example 1343 created
# Example 1344 created
# Example 1345 created
# Example 1346 created
# Example 1347 created
# Example 1348 created
# Example 1349 created
# Example 1350 created
# Example 1351 created
# Example 1352 created
# Example 1353 created
# Example 1354 created
# Example 1355 created
# Example 1356 created
# Example 1357 created
# Example 1358 created
# Example 1359 created
# Example 1360 created
# Example 1361 created
# Example 1362 created
# Example 1363 created
# Example 1364 created
# Example 1365 created
# Example 1366 created
# Example 1367 created
# Example 1368 created
# Example 1369 created
# Example 1370 created
# Example 1371 created
# Example 1372 created
# Example 1373 created
# Example 1374 created
# Example 1375 created
# Example 1376 created
# Example 1377 created
# Example 1378 created
# Example 1379 created
# Example 1380 created
# Example 1381 created
# Example 1382 created
# Example 1383 created
# Example 1384 created
# Example 1385 created
# Example 1386 created
# Example 1387 created
# Example 1388 created
# Example 1389 created
# Example 1390 created
# Example 1391 created
# Example 1392 created
# Example 1393 created
# Example 1394 created
# Example 1395 created
# Example 1396 created
# Example 1397 created
# Example 1398 created
# Example 1399 created
# Example 1400 created
# Example 1401 created
# Example 1402 created
# Example 1403 created
# Example 1404 created
# Example 1405 created
# Example 1406 created
# Example 1407 created
# Example 1408 created
# Example 1409 created
# Example 1410 created
# Example 1411 created
# Example 1412 created
# Example 1413 created
# Example 1414 created
# Example 1415 created
# Example 1416 created
# Example 1417 created
# Example 1418 created
# Example 1419 created
# Example 1420 created
# Example 1421 created
# Example 1422 created
# Example 1423 created
# Example 1424 created
# Example 1425 created
# Example 1426 created
# Example 1427 created
# Example 1428 created
# Example 1429 created
# Example 1430 created
# Example 1431 created
# Example 1432 created
# Example 1433 created
# Example 1434 created
# Example 1435 created
# Example 1436 created
# Example 1437 created
# Example 1438 created
# Example 1439 created
# Example 1440 created
# Example 1441 created
# Example 1442 created
# Example 1443 created
# Example 1444 created
# Example 1445 created
# Example 1446 created
# Example 1447 created
# Example 1448 created
# Example 1449 created
# Example 1450 created
# Example 1451 created
# Example 1452 created
# Example 1453 created
# Example 1454 created
# Example 1455 created
# Example 1456 created
# Example 1457 created
# Example 1458 created
# Example 1459 created
# Example 1460 created
# Example 1461 created
# Example 1462 created
# Example 1463 created
# Example 1464 created
# Example 1465 created
# Example 1466 created
# Example 1467 created
# Example 1468 created
# Example 1469 created
# Example 1470 created
# Example 1471 created
# Example 1472 created
# Example 1473 created
# Example 1474 created
# Example 1475 created
# Example 1476 created
# Example 1477 created
# Example 1478 created
# Example 1479 created
# Example 1480 created
# Example 1481 created
# Example 1482 created
# Example 1483 created
# Example 1484 created
# Example 1485 created
# Example 1486 created
# Example 1487 created
# Example 1488 created
# Example 1489 created
# Example 1490 created
# Example 1491 created
# Example 1492 created
# Example 1493 created
# Example 1494 created
# Example 1495 created
# Example 1496 created
# Example 1497 created
# Example 1498 created
# Example 1499 created
# Example 1500 created
# Example 1501 created
# Example 1502 created
# Example 1503 created
# Example 1504 created
# Example 1505 created
# Example 1506 created
# Example 1507 created
# Example 1508 created
# Example 1509 created
# Example 1510 created
# Example 1511 created
# Example 1512 created
# Example 1513 created
# Example 1514 created
# Example 1515 created
# Example 1516 created
# Example 1517 created
# Example 1518 created
# Example 1519 created
# Example 1520 created
# Example 1521 created
# Example 1522 created
# Example 1523 created
# Example 1524 created
# Example 1525 created
# Example 1526 created
# Example 1527 created
# Example 1528 created
# Example 1529 created
# Example 1530 created
# Example 1531 created
# Example 1532 created
# Example 1533 created
# Example 1534 created
# Example 1535 created
# Example 1536 created
# Example 1537 created
# Example 1538 created
# Example 1539 created
# Example 1540 created
# Example 1541 created
# Example 1542 created
# Example 1543 created
# Example 1544 created
# Example 1545 created
# Example 1546 created
# Example 1547 created
# Example 1548 created
# Example 1549 created
# Example 1550 created
# Example 1551 created
# Example 1552 created
# Example 1553 created
# Example 1554 created
# Example 1555 created
# Example 1556 created
# Example 1557 created
# Example 1558 created
# Example 1559 created
# Example 1560 created
# Example 1561 created
# Example 1562 created
# Example 1563 created
# Example 1564 created
# Example 1565 created
# Example 1566 created
# Example 1567 created
# Example 1568 created
# Example 1569 created
# Example 1570 created
# Example 1571 created
# Example 1572 created
# Example 1573 created
# Example 1574 created
# Example 1575 created
# Example 1576 created
# Example 1577 created
# Example 1578 created
# Example 1579 created
# Example 1580 created
# Example 1581 created
# Example 1582 created
# Example 1583 created
# Example 1584 created
# Example 1585 created
# Example 1586 created
# Example 1587 created
# Example 1588 created
# Example 1589 created
# Example 1590 created
# Example 1591 created
# Example 1592 created
# Example 1593 created
# Example 1594 created
# Example 1595 created
# Example 1596 created
# Example 1597 created
# Example 1598 created
# Example 1599 created
# Example 1600 created
# Example 1601 created
# Example 1602 created
# Example 1603 created
# Example 1604 created
# Example 1605 created
# Example 1606 created
# Example 1607 created
# Example 1608 created
# Example 1609 created
# Example 1610 created
# Example 1611 created
# Example 1612 created
# Example 1613 created
# Example 1614 created
# Example 1615 created
# Example 1616 created
# Example 1617 created
# Example 1618 created
# Example 1619 created
# Example 1620 created
# Example 1621 created
# Example 1622 created
# Example 1623 created
# Example 1624 created
# Example 1625 created
# Example 1626 created
# Example 1627 created
# Example 1628 created
# Example 1629 created
# Example 1630 created
# Example 1631 created
# Example 1632 created
# Example 1633 created
# Example 1634 created
# Example 1635 created
# Example 1636 created
# Example 1637 created
# Example 1638 created
# Example 1639 created
# Example 1640 created
# Example 1641 created
# Example 1642 created
# Example 1643 created
# Example 1644 created
# Example 1645 created
# Example 1646 created
# Example 1647 created
# Example 1648 created
# Example 1649 created
# Example 1650 created
# Example 1651 created
# Example 1652 created
# Example 1653 created
# Example 1654 created
# Example 1655 created
# Example 1656 created
# Example 1657 created
# Example 1658 created
# Example 1659 created
# Example 1660 created
# Example 1661 created
# Example 1662 created
# Example 1663 created
# Example 1664 created
# Example 1665 created
# Example 1666 created
# Example 1667 created
# Example 1668 created
# Example 1669 created
# Example 1670 created
# Example 1671 created
# Example 1672 created
# Example 1673 created
# Example 1674 created
# Example 1675 created
# Example 1676 created
# Example 1677 created
# Example 1678 created
# Example 1679 created
# Example 1680 created
# Example 1681 created
# Example 1682 created
# Example 1683 created
# Example 1684 created
# Example 1685 created
# Example 1686 created
# Example 1687 created
# Example 1688 created
# Example 1689 created
# Example 1690 created
# Example 1691 created
# Example 1692 created
# Example 1693 created
# Example 1694 created
# Example 1695 created
# Example 1696 created
# Example 1697 created
# Example 1698 created
# Example 1699 created
# Example 1700 created
# Example 1701 created
# Example 1702 created
# Example 1703 created
# Example 1704 created
# Example 1705 created
# Example 1706 created
# Example 1707 created
# Example 1708 created
# Example 1709 created
# Example 1710 created
# Example 1711 created
# Example 1712 created
# Example 1713 created
# Example 1714 created
# Example 1715 created
# Example 1716 created
# Example 1717 created
# Example 1718 created
# Example 1719 created
# Example 1720 created
# Example 1721 created
# Example 1722 created
# Example 1723 created
# Example 1724 created
# Example 1725 created
# Example 1726 created
# Example 1727 created
# Example 1728 created
# Example 1729 created
# Example 1730 created
# Example 1731 created
# Example 1732 created
# Example 1733 created
# Example 1734 created
# Example 1735 created
# Example 1736 created
# Example 1737 created
# Example 1738 created
# Example 1739 created
# Example 1740 created
# Example 1741 created
# Example 1742 created
# Example 1743 created
# Example 1744 created
# Example 1745 created
# Example 1746 created
# Example 1747 created
# Example 1748 created
# Example 1749 created
# Example 1750 created
# Example 1751 created
# Example 1752 created
# Example 1753 created
# Example 1754 created
# Example 1755 created
# Example 1756 created
# Example 1757 created
# Example 1758 created
# Example 1759 created
# Example 1760 created
# Example 1761 created
# Example 1762 created
# Example 1763 created
# Example 1764 created
# Example 1765 created
# Example 1766 created
# Example 1767 created
# Example 1768 created
# Example 1769 created
# Example 1770 created
# Example 1771 created
# Example 1772 created
# Example 1773 created
# Example 1774 created
# Example 1775 created
# Example 1776 created
# Example 1777 created
# Example 1778 created
# Example 1779 created
# Example 1780 created
# Example 1781 created
# Example 1782 created
# Example 1783 created
# Example 1784 created
# Example 1785 created
# Example 1786 created
# Example 1787 created
# Example 1788 created
# Example 1789 created
# Example 1790 created
# Example 1791 created
# Example 1792 created
# Example 1793 created
# Example 1794 created
# Example 1795 created
# Example 1796 created
# Example 1797 created
# Example 1798 created
# Example 1799 created
# Example 1800 created
# Example 1801 created
# Example 1802 created
# Example 1803 created
# Example 1804 created
# Example 1805 created
# Example 1806 created
# Example 1807 created
# Example 1808 created
# Example 1809 created
# Example 1810 created
# Example 1811 created
# Example 1812 created
# Example 1813 created
# Example 1814 created
# Example 1815 created
# Example 1816 created
# Example 1817 created
# Example 1818 created
# Example 1819 created
# Example 1820 created
# Example 1821 created
# Example 1822 created
# Example 1823 created
# Example 1824 created
# Example 1825 created
# Example 1826 created
# Example 1827 created
# Example 1828 created
# Example 1829 created
# Example 1830 created
# Example 1831 created
# Example 1832 created
# Example 1833 created
# Example 1834 created
# Example 1835 created
# Example 1836 created
# Example 1837 created
# Example 1838 created
# Example 1839 created
# Example 1840 created
# Example 1841 created
# Example 1842 created
# Example 1843 created
# Example 1844 created
# Example 1845 created
# Example 1846 created
# Example 1847 created
# Example 1848 created
# Example 1849 created
# Example 1850 created
# Example 1851 created
# Example 1852 created
# Example 1853 created
# Example 1854 created
# Example 1855 created
# Example 1856 created
# Example 1857 created
# Example 1858 created
# Example 1859 created
# Example 1860 created
# Example 1861 created
# Example 1862 created
# Example 1863 created
# Example 1864 created
# Example 1865 created
# Example 1866 created
# Example 1867 created
# Example 1868 created
# Example 1869 created
# Example 1870 created
# Example 1871 created
# Example 1872 created
# Example 1873 created
# Example 1874 created
# Example 1875 created
# Example 1876 created
# Example 1877 created
# Example 1878 created
# Example 1879 created
# Example 1880 created
# Example 1881 created
# Example 1882 created
# Example 1883 created
# Example 1884 created
# Example 1885 created
# Example 1886 created
# Example 1887 created
# Example 1888 created
# Example 1889 created
# Example 1890 created
# Example 1891 created
# Example 1892 created
# Example 1893 created
# Example 1894 created
# Example 1895 created
# Example 1896 created
# Example 1897 created
# Example 1898 created
# Example 1899 created
# Example 1900 created
# Example 1901 created
# Example 1902 created
# Example 1903 created
# Example 1904 created
# Example 1905 created
# Example 1906 created
# Example 1907 created
# Example 1908 created
# Example 1909 created
# Example 1910 created
# Example 1911 created
# Example 1912 created
# Example 1913 created
# Example 1914 created
# Example 1915 created
# Example 1916 created
# Example 1917 created
# Example 1918 created
# Example 1919 created
# Example 1920 created
# Example 1921 created
# Example 1922 created
# Example 1923 created
# Example 1924 created
# Example 1925 created
# Example 1926 created
# Example 1927 created
# Example 1928 created
# Example 1929 created
# Example 1930 created
# Example 1931 created
# Example 1932 created
# Example 1933 created
# Example 1934 created
# Example 1935 created
# Example 1936 created
# Example 1937 created
# Example 1938 created
# Example 1939 created
# Example 1940 created
# Example 1941 created
# Example 1942 created
# Example 1943 created
# Example 1944 created
# Example 1945 created
# Example 1946 created
# Example 1947 created
# Example 1948 created
# Example 1949 created
# Example 1950 created
# Example 1951 created
# Example 1952 created
# Example 1953 created
# Example 1954 created
# Example 1955 created
# Example 1956 created
# Example 1957 created
# Example 1958 created
# Example 1959 created
# Example 1960 created
# Example 1961 created
# Example 1962 created
# Example 1963 created
# Example 1964 created
# Example 1965 created
# Example 1966 created
# Example 1967 created
# Example 1968 created
# Example 1969 created
# Example 1970 created
# Example 1971 created
# Example 1972 created
# Example 1973 created
# Example 1974 created
# Example 1975 created
# Example 1976 created
# Example 1977 created
# Example 1978 created
# Example 1979 created
# Example 1980 created
# Example 1981 created
# Example 1982 created
# Example 1983 created
# Example 1984 created
# Example 1985 created
# Example 1986 created
# Example 1987 created
# Example 1988 created
# Example 1989 created
# Example 1990 created
# Example 1991 created
# Example 1992 created
# Example 1993 created
# Example 1994 created
# Example 1995 created
# Example 1996 created
# Example 1997 created
# Example 1998 created
# Example 1999 created
# Example 2000 created
# Example 2001 created
# Example 2002 created
# Example 2003 created
# Example 2004 created
# Example 2005 created
# Example 2006 created
# Example 2007 created
# Example 2008 created
# Example 2009 created
# Example 2010 created
# Example 2011 created
# Example 2012 created
# Example 2013 created
# Example 2014 created
# Example 2015 created
# Example 2016 created
# Example 2017 created
# Example 2018 created
# Example 2019 created
# Example 2020 created
# Example 2021 created
# Example 2022 created
# Example 2023 created
# Example 2024 created
# Example 2025 created
# Example 2026 created
# Example 2027 created
# Example 2028 created
# Example 2029 created
# Example 2030 created
# Example 2031 created
# Example 2032 created
# Example 2033 created
# Example 2034 created
# Example 2035 created
# Example 2036 created
# Example 2037 created
# Example 2038 created
# Example 2039 created
# Example 2040 created
# Example 2041 created
# Example 2042 created
# Example 2043 created
# Example 2044 created
# Example 2045 created
# Example 2046 created
# Example 2047 created
# Example 2048 created
# Example 2049 created
# Example 2050 created
# Example 2051 created
# Example 2052 created
# Example 2053 created
# Example 2054 created
# Example 2055 created
# Example 2056 created
# Example 2057 created
# Example 2058 created
# Example 2059 created
# Example 2060 created
# Example 2061 created
# Example 2062 created
# Example 2063 created
# Example 2064 created
# Example 2065 created
# Example 2066 created
# Example 2067 created
# Example 2068 created
# Example 2069 created
# Example 2070 created
# Example 2071 created
# Example 2072 created
# Example 2073 created
# Example 2074 created
# Example 2075 created
# Example 2076 created
# Example 2077 created
# Example 2078 created
# Example 2079 created
# Example 2080 created
# Example 2081 created
# Example 2082 created
# Example 2083 created
# Example 2084 created
# Example 2085 created
# Example 2086 created
# Example 2087 created
# Example 2088 created
# Example 2089 created
# Example 2090 created
# Example 2091 created
# Example 2092 created
# Example 2093 created
# Example 2094 created
# Example 2095 created
# Example 2096 created
# Example 2097 created
# Example 2098 created
# Example 2099 created
# Example 2100 created
# Example 2101 created
# Example 2102 created
# Example 2103 created
# Example 2104 created
# Example 2105 created
# Example 2106 created
# Example 2107 created
# Example 2108 created
# Example 2109 created
# Example 2110 created
# Example 2111 created
# Example 2112 created
# Example 2113 created
# Example 2114 created
# Example 2115 created
# Example 2116 created
# Example 2117 created
# Example 2118 created
# Example 2119 created
# Example 2120 created
# Example 2121 created
# Example 2122 created
# Example 2123 created
# Example 2124 created
# Example 2125 created
# Example 2126 created
# Example 2127 created
# Example 2128 created
# Example 2129 created
# Example 2130 created
# Example 2131 created
# Example 2132 created
# Example 2133 created
# Example 2134 created
# Example 2135 created
# Example 2136 created
# Example 2137 created
# Example 2138 created
# Example 2139 created
# Example 2140 created
# Example 2141 created
# Example 2142 created
# Example 2143 created
# Example 2144 created
# Example 2145 created
# Example 2146 created
# Example 2147 created
# Example 2148 created
# Example 2149 created
# Example 2150 created
# Example 2151 created
# Example 2152 created
# Example 2153 created
# Example 2154 created
# Example 2155 created
# Example 2156 created
# Example 2157 created
# Example 2158 created
# Example 2159 created
# Example 2160 created
# Example 2161 created
# Example 2162 created
# Example 2163 created
# Example 2164 created
# Example 2165 created
# Example 2166 created
# Example 2167 created
# Example 2168 created
# Example 2169 created
# Example 2170 created
# Example 2171 created
# Example 2172 created
# Example 2173 created
# Example 2174 created
# Example 2175 created
# Example 2176 created
# Example 2177 created
# Example 2178 created
# Example 2179 created
# Example 2180 created
# Example 2181 created
# Example 2182 created
# Example 2183 created
# Example 2184 created
# Example 2185 created
# Example 2186 created
# Example 2187 created
# Example 2188 created
# Example 2189 created
# Example 2190 created
# Example 2191 created
# Example 2192 created
# Example 2193 created
# Example 2194 created
# Example 2195 created
# Example 2196 created
# Example 2197 created
# Example 2198 created
# Example 2199 created
# Example 2200 created
# Example 2201 created
# Example 2202 created
# Example 2203 created
# Example 2204 created
# Example 2205 created
# Example 2206 created
# Example 2207 created
# Example 2208 created
# Example 2209 created
# Example 2210 created
# Example 2211 created
# Example 2212 created
# Example 2213 created
# Example 2214 created
# Example 2215 created
# Example 2216 created
# Example 2217 created
# Example 2218 created
# Example 2219 created
# Example 2220 created
# Example 2221 created
# Example 2222 created
# Example 2223 created
# Example 2224 created
# Example 2225 created
# Example 2226 created
# Example 2227 created
# Example 2228 created
# Example 2229 created
# Example 2230 created
# Example 2231 created
# Example 2232 created
# Example 2233 created
# Example 2234 created
# Example 2235 created
# Example 2236 created
# Example 2237 created
# Example 2238 created
# Example 2239 created
# Example 2240 created
# Example 2241 created
# Example 2242 created
# Example 2243 created
# Example 2244 created
# Example 2245 created
# Example 2246 created
# Example 2247 created
# Example 2248 created
# Example 2249 created
# Example 2250 created
# Example 2251 created
# Example 2252 created
# Example 2253 created
# Example 2254 created
# Example 2255 created
# Example 2256 created
# Example 2257 created
# Example 2258 created
# Example 2259 created
# Example 2260 created
# Example 2261 created
# Example 2262 created
# Example 2263 created
# Example 2264 created
# Example 2265 created
# Example 2266 created
# Example 2267 created
# Example 2268 created
# Example 2269 created
# Example 2270 created
# Example 2271 created
# Example 2272 created
# Example 2273 created
# Example 2274 created
# Example 2275 created
# Example 2276 created
# Example 2277 created
# Example 2278 created
# Example 2279 created
# Example 2280 created
# Example 2281 created
# Example 2282 created
# Example 2283 created
# Example 2284 created
# Example 2285 created
# Example 2286 created
# Example 2287 created
# Example 2288 created
# Example 2289 created
# Example 2290 created
# Example 2291 created
# Example 2292 created
# Example 2293 created
# Example 2294 created
# Example 2295 created
# Example 2296 created
# Example 2297 created
# Example 2298 created
# Example 2299 created
# Example 2300 created
# Example 2301 created
# Example 2302 created
# Example 2303 created
# Example 2304 created
# Example 2305 created
# Example 2306 created
# Example 2307 created
# Example 2308 created
# Example 2309 created
# Example 2310 created
# Example 2311 created
# Example 2312 created
# Example 2313 created
# Example 2314 created
# Example 2315 created
# Example 2316 created
# Example 2317 created
# Example 2318 created
# Example 2319 created
# Example 2320 created
# Example 2321 created
# Example 2322 created
# Example 2323 created
# Example 2324 created
# Example 2325 created
# Example 2326 created
# Example 2327 created
# Example 2328 created
# Example 2329 created
# Example 2330 created
# Example 2331 created
# Example 2332 created
# Example 2333 created
# Example 2334 created
# Example 2335 created
# Example 2336 created
# Example 2337 created
# ...
# Example 28415 created
# Example 28416 created
# Example 28417 created
# Example 28418 created
# Example 28419 created
# Example 28420 created
# Example 28421 created
# Example 28422 created
# Example 28423 created
# Example 28424 created
# Example 28425 created
# Example 28426 created
# Example 28427 created
# Example 28428 created
# Example 28429 created
# Example 28430 created
# Example 28431 created
# Example 28432 created
# Example 28433 created
# Example 28434 created
# Example 28435 created
# Example 28436 created
# Example 28437 created
# Example 28438 created
# Example 28439 created
# Example 28440 created
# Example 28441 created
# Example 28442 created
# Example 28443 created
# Example 28444 created
# Example 28445 created
# Example 28446 created
# Example 28447 created
# Example 28448 created
# Example 28449 created
# Example 28450 created
# Example 28451 created
# Example 28452 created
# Example 28453 created
# Example 28454 created
# Example 28455 created
# Example 28456 created
# Example 28457 created
# Example 28458 created
# Example 28459 created
# Example 28460 created
# Example 28461 created
# Example 28462 created
# Example 28463 created
# Example 28464 created
# Example 28465 created
# Example 28466 created
# Example 28467 created
# Example 28468 created
# Example 28469 created
# Example 28470 created
# Example 28471 created
# Example 28472 created
# Example 28473 created
# Example 28474 created
# Example 28475 created
# Example 28476 created
# Example 28477 created
# Example 28478 created
# Example 28479 created
# Example 28480 created
# Example 28481 created
# Example 28482 created
# Example 28483 created
# Example 28484 created
# Example 28485 created
# Example 28486 created
# Example 28487 created
# Example 28488 created
# Example 28489 created
# Example 28490 created
# Example 28491 created
# Example 28492 created
# Example 28493 created
# Example 28494 created
# Example 28495 created
# Example 28496 created
# Example 28497 created
# Example 28498 created
# Example 28499 created
# Example 28500 created
# Example 28501 created
# Example 28502 created
# Example 28503 created
# Example 28504 created
# Example 28505 created
# Example 28506 created
# Example 28507 created
# Example 28508 created
# Example 28509 created
# Example 28510 created
# Example 28511 created
# Example 28512 created
# Example 28513 created
# Example 28514 created
# Example 28515 created
# Example 28516 created
# Example 28517 created
# Example 28518 created
# Example 28519 created
# Example 28520 created
# Example 28521 created
# Example 28522 created
# Example 28523 created
# Example 28524 created
# Example 28525 created
# Example 28526 created
# Example 28527 created
# Example 28528 created
# Example 28529 created
# Example 28530 created
# Example 28531 created
# Example 28532 created
# Example 28533 created
# Example 28534 created
# Example 28535 created
# Example 28536 created
# Example 28537 created
# Example 28538 created
# Example 28539 created
# Example 28540 created
# Example 28541 created
# Example 28542 created
# Example 28543 created
# Example 28544 created
# Example 28545 created
# Example 28546 created
# Example 28547 created
# Example 28548 created
# Example 28549 created
# Example 28550 created
# Example 28551 created
# Example 28552 created
# Example 28553 created
# Example 28554 created
# Example 28555 created
# Example 28556 created
# Example 28557 created
# Example 28558 created
# Example 28559 created
# Example 28560 created
# Example 28561 created
# Example 28562 created
# Example 28563 created
# Example 28564 created
# Example 28565 created
# Example 28566 created
# Example 28567 created
# Example 28568 created
# Example 28569 created
# Example 28570 created
# Example 28571 created
# Example 28572 created
# Example 28573 created
# Example 28574 created
# Example 28575 created
# Example 28576 created
# Example 28577 created
# Example 28578 created
# Example 28579 created
# Example 28580 created
# Example 28581 created
# Example 28582 created
# Example 28583 created
# Example 28584 created
# Example 28585 created
# Example 28586 created
# Example 28587 created
# Example 28588 created
# Example 28589 created
# Example 28590 created
# Example 28591 created
# Example 28592 created
# Example 28593 created
# Example 28594 created
# Example 28595 created
# Example 28596 created
# Example 28597 created
# Example 28598 created
# Example 28599 created
# Example 28600 created
# Example 28601 created
# Example 28602 created
# Example 28603 created
# Example 28604 created
# Example 28605 created
# Example 28606 created
# Example 28607 created
# Example 28608 created
# Example 28609 created
# Example 28610 created
# Example 28611 created
# Example 28612 created
# Example 28613 created
# Example 28614 created
# Example 28615 created
# Example 28616 created
# Example 28617 created
# Example 28618 created
# Example 28619 created
# Example 28620 created
# Example 28621 created
# Example 28622 created
# Example 28623 created
# Example 28624 created
# Example 28625 created
# Example 28626 created
# Example 28627 created
# Example 28628 created
# Example 28629 created
# Example 28630 created
# Example 28631 created
# Example 28632 created
# Example 28633 created
# Example 28634 created
# Example 28635 created
# Example 28636 created
# Example 28637 created
# Example 28638 created
# Example 28639 created
# Example 28640 created
# Example 28641 created
# Example 28642 created
# Example 28643 created
# Example 28644 created
# Example 28645 created
# Example 28646 created
# Example 28647 created
# Example 28648 created
# Example 28649 created
# Example 28650 created
# Example 28651 created
# Example 28652 created
# Example 28653 created
# Example 28654 created
# Example 28655 created
# Example 28656 created
# Example 28657 created
# Example 28658 created
# Example 28659 created
# Example 28660 created
# Example 28661 created
# Example 28662 created
# Example 28663 created
# Example 28664 created
# Example 28665 created
# Example 28666 created
# Example 28667 created
# Example 28668 created
# Example 28669 created
# Example 28670 created
# Example 28671 created
# Example 28672 created
# Example 28673 created
# Example 28674 created
# Example 28675 created
# Example 28676 created
# Example 28677 created
# Example 28678 created
# Example 28679 created
# Example 28680 created
# Example 28681 created
# Example 28682 created
# Example 28683 created
# Example 28684 created
# Example 28685 created
# Example 28686 created
# Example 28687 created
# Example 28688 created
# Example 28689 created
# Example 28690 created
# Example 28691 created
# Example 28692 created
# Example 28693 created
# Example 28694 created
# Example 28695 created
# Example 28696 created
# Example 28697 created
# Example 28698 created
# Example 28699 created
# Example 28700 created
# Example 28701 created
# Example 28702 created
# Example 28703 created
# Example 28704 created
# Example 28705 created
# Example 28706 created
# Example 28707 created
# Example 28708 created
# Example 28709 created
# Example 28710 created
# Example 28711 created
# Example 28712 created
# Example 28713 created
# Example 28714 created
# Example 28715 created
# Example 28716 created
# Example 28717 created
# Example 28718 created
# Example 28719 created
# Example 28720 created
# Example 28721 created
# Example 28722 created
# Example 28723 created
# Example 28724 created
# Example 28725 created
# Example 28726 created
# Example 28727 created
# Example 28728 created
# Example 28729 created
# Example 28730 created
# Example 28731 created
# Example 28732 created
# Example 28733 created
# Example 28734 created
# Example 28735 created
# Example 28736 created
# Example 28737 created
# Example 28738 created
# Example 28739 created
# Example 28740 created
# Example 28741 created
# Example 28742 created
# Example 28743 created
# Example 28744 created
# Example 28745 created
# Example 28746 created
# Example 28747 created
# Example 28748 created
# Example 28749 created
# Example 28750 created
# Example 28751 created
# Example 28752 created
# Example 28753 created
# Example 28754 created
# Example 28755 created
# Example 28756 created
# Example 28757 created
# Example 28758 created
# Example 28759 created
# Example 28760 created
# Example 28761 created
# Example 28762 created
# Example 28763 created
# Example 28764 created
# Example 28765 created
# Example 28766 created
# Example 28767 created
# Example 28768 created
# Example 28769 created
# Example 28770 created
# Example 28771 created
# Example 28772 created
# Example 28773 created
# Example 28774 created
# Example 28775 created
# Example 28776 created
# Example 28777 created
# Example 28778 created
# Example 28779 created
# Example 28780 created
# Example 28781 created
# Example 28782 created
# Example 28783 created
# Example 28784 created
# Example 28785 created
# Example 28786 created
# Example 28787 created
# Example 28788 created
# Example 28789 created
# Example 28790 created
# Example 28791 created
# Example 28792 created
# Example 28793 created
# Example 28794 created
# Example 28795 created
# Example 28796 created
# Example 28797 created
# Example 28798 created
# Example 28799 created
# Example 28800 created
# Example 28801 created
# Example 28802 created
# Example 28803 created
# Example 28804 created
# Example 28805 created
# Example 28806 created
# Example 28807 created
# Example 28808 created
# Example 28809 created
# Example 28810 created
# Example 28811 created
# Example 28812 created
# Example 28813 created
# Example 28814 created
# Example 28815 created
# Example 28816 created
# Example 28817 created
# Example 28818 created
# Example 28819 created
# Example 28820 created
# Example 28821 created
# Example 28822 created
# Example 28823 created
# Example 28824 created
# Example 28825 created
# Example 28826 created
# Example 28827 created
# Example 28828 created
# Example 28829 created
# Example 28830 created
# Example 28831 created
# Example 28832 created
# Example 28833 created
# Example 28834 created
# Example 28835 created
# Example 28836 created
# Example 28837 created
# Example 28838 created
# Example 28839 created
# Example 28840 created
# Example 28841 created
# Example 28842 created
# Example 28843 created
# Example 28844 created
# Example 28845 created
# Example 28846 created
# Example 28847 created
# Example 28848 created
# Example 28849 created
# Example 28850 created
# Example 28851 created
# Example 28852 created
# Example 28853 created
# Example 28854 created
# Example 28855 created
# Example 28856 created
# Example 28857 created
# Example 28858 created
# Example 28859 created
# Example 28860 created
# Example 28861 created
# Example 28862 created
# Example 28863 created
# Example 28864 created
# Example 28865 created
# Example 28866 created
# Example 28867 created
# Example 28868 created
# Example 28869 created
# Example 28870 created
# Example 28871 created
# Example 28872 created
# Example 28873 created
# Example 28874 created
# Example 28875 created
# Example 28876 created
# Example 28877 created
# Example 28878 created
# Example 28879 created
# Example 28880 created
# Example 28881 created
# Example 28882 created
# Example 28883 created
# Example 28884 created
# Example 28885 created
# Example 28886 created
# Example 28887 created
# Example 28888 created
# Example 28889 created
# Example 28890 created
# Example 28891 created
# Example 28892 created
# Example 28893 created
# Example 28894 created
# Example 28895 created
# Example 28896 created
# Example 28897 created
# Example 28898 created
# Example 28899 created
# Example 28900 created
# Example 28901 created
# Example 28902 created
# Example 28903 created
# Example 28904 created
# Example 28905 created
# Example 28906 created
# Example 28907 created
# Example 28908 created
# Example 28909 created
# Example 28910 created
# Example 28911 created
# Example 28912 created
# Example 28913 created
# Example 28914 created
# Example 28915 created
# Example 28916 created
# Example 28917 created
# Example 28918 created
# Example 28919 created
# Example 28920 created
# Example 28921 created
# Example 28922 created
# Example 28923 created
# Example 28924 created
# Example 28925 created
# Example 28926 created
# Example 28927 created
# Example 28928 created
# Example 28929 created
# Example 28930 created
# Example 28931 created
# Example 28932 created
# Example 28933 created
# Example 28934 created
# Example 28935 created
# Example 28936 created
# Example 28937 created
# Example 28938 created
# Example 28939 created
# Example 28940 created
# Example 28941 created
# Example 28942 created
# Example 28943 created
# Example 28944 created
# Example 28945 created
# Example 28946 created
# Example 28947 created
# Example 28948 created
# Example 28949 created
# Example 28950 created
# Example 28951 created
# Example 28952 created
# Example 28953 created
# Example 28954 created
# Example 28955 created
# Example 28956 created
# Example 28957 created
# Example 28958 created
# Example 28959 created
# Example 28960 created
# Example 28961 created
# Example 28962 created
# Example 28963 created
# Example 28964 created
# Example 28965 created
# Example 28966 created
# Example 28967 created
# Example 28968 created
# Example 28969 created
# Example 28970 created
# Example 28971 created
# Example 28972 created
# Example 28973 created
# Example 28974 created
# Example 28975 created
# Example 28976 created
# Example 28977 created
# Example 28978 created
# Example 28979 created
# Example 28980 created
# Example 28981 created
# Example 28982 created
# Example 28983 created
# Example 28984 created
# Example 28985 created
# Example 28986 created
# Example 28987 created
# Example 28988 created
# Example 28989 created
# Example 28990 created
# Example 28991 created
# Example 28992 created
# Example 28993 created
# Example 28994 created
# Example 28995 created
# Example 28996 created
# Example 28997 created
# Example 28998 created
# Example 28999 created
# Example 29000 created
# Example 29001 created
# Example 29002 created
# Example 29003 created
# Example 29004 created
# Example 29005 created
# Example 29006 created
# Example 29007 created
# Example 29008 created
# Example 29009 created
# Example 29010 created
# Example 29011 created
# Example 29012 created
# Example 29013 created
# Example 29014 created
# Example 29015 created
# Example 29016 created
# Example 29017 created
# Example 29018 created
# Example 29019 created
# Example 29020 created
# Example 29021 created
# Example 29022 created
# Example 29023 created
# Example 29024 created
# Example 29025 created
# Example 29026 created
# Example 29027 created
# Example 29028 created
# Example 29029 created
# Example 29030 created
# Example 29031 created
# Example 29032 created
# Example 29033 created
# Example 29034 created
# Example 29035 created
# Example 29036 created
# Example 29037 created
# Example 29038 created
# Example 29039 created
# Example 29040 created
# Example 29041 created
# Example 29042 created
# Example 29043 created
# Example 29044 created
# Example 29045 created
# Example 29046 created
# Example 29047 created
# Example 29048 created
# Example 29049 created
# Example 29050 created
# Example 29051 created
# Example 29052 created
# Example 29053 created
# Example 29054 created
# Example 29055 created
# Example 29056 created
# Example 29057 created
# Example 29058 created
# Example 29059 created
# Example 29060 created
# Example 29061 created
# Example 29062 created
# Example 29063 created
# Example 29064 created
# Example 29065 created
# Example 29066 created
# Example 29067 created
# Example 29068 created
# Example 29069 created
# Example 29070 created
# Example 29071 created
# Example 29072 created
# Example 29073 created
# Example 29074 created
# Example 29075 created
# Example 29076 created
# Example 29077 created
# Example 29078 created
# Example 29079 created
# Example 29080 created
# Example 29081 created
# Example 29082 created
# Example 29083 created
# Example 29084 created
# Example 29085 created
# Example 29086 created
# Example 29087 created
# Example 29088 created
# Example 29089 created
# Example 29090 created
# Example 29091 created
# Example 29092 created
# Example 29093 created
# Example 29094 created
# Example 29095 created
# Example 29096 created
# Example 29097 created
# Example 29098 created
# Example 29099 created
# Example 29100 created
# Example 29101 created
# Example 29102 created
# Example 29103 created
# Example 29104 created
# Example 29105 created
# Example 29106 created
# Example 29107 created
# Example 29108 created
# Example 29109 created
# Example 29110 created
# Example 29111 created
# Example 29112 created
# Example 29113 created
# Example 29114 created
# Example 29115 created
# Example 29116 created
# Example 29117 created
# Example 29118 created
# Example 29119 created
# Example 29120 created
# Example 29121 created
# Example 29122 created
# Example 29123 created
# Example 29124 created
# Example 29125 created
# Example 29126 created
# Example 29127 created
# Example 29128 created
# Example 29129 created
# Example 29130 created
# Example 29131 created
# Example 29132 created
# Example 29133 created
# Example 29134 created
# Example 29135 created
# Example 29136 created
# Example 29137 created
# Example 29138 created
# Example 29139 created
# Example 29140 created
# Example 29141 created

# %%
print("training_examples first element:")
print(training_examples[0])
print("---------------------------------------------------------------")
print("position_index_pairs_all first element:")
print(position_index_pairs_all[0])
# Out:
# training_examples first element:
# carfree city become subject increase interest debate recent year urban area around world grapple challenge congestion pollution limited resource concept carfree city involves create urban environment private automobile either significantly restrict completely ban focus alternative transportation method sustainable urban planning essay explores benefit challenge potential solution associate idea carfree city
# ---------------------------------------------------------------
# position_index_pairs_all first element:
# [(36, 243)]

# %% [markdown]
# ### Calculation word numbers in esseys

# %%
def text_to_tensor(text, tokenizer, position_index_pairs_all):
    # Tokenize the text
    tokens = tokenizer.texts_to_sequences([text])[0]
    tensor_representation = []

    # Iterate through the tokens
    for i, token in enumerate(tokens):
        tensor_representation.append(token)

    return tensor_representation

missing_word_index = tokenizer_vocab_df.index[tokenizer_vocab_df['Word'] == "<MISSING>"][0]
unknown_word_index = tokenizer_vocab_df.index[tokenizer_vocab_df['Word'] == "<UNK>"][0]

# Calculate average and minimum length of essays
essay_lengths = [len(text.split()) for text in df['clean_text']]
average_length = sum(essay_lengths) / len(essay_lengths)
min_length = min(essay_lengths)

# Vectorization
max_sequence_length = 50

essays_tensor = []

# Iterate through each essay
k = 0
padding_index = -1
for essay, position_index_pair in zip(training_examples, position_index_pairs_all):
    tokens = essay.split()
    token_indices = []

    # Convert each token to its corresponding index in the vocabulary
    for i, token in enumerate(tokens):
        if any(position == i for position, _ in position_index_pair):
            # Missing word
            token_indices.append(missing_word_index)
        else:
            index = tokenizer_vocab_df[tokenizer_vocab_df['Word'] == token]['Index'].values
            if len(index) > 0:
                token_indices.append(index[0])
            else:
                # If the token is not in the vocabulary -> unknown token
                token_indices.append(unknown_word_index)

    # Pad the sequence to the maximum length
    if len(token_indices) > max_sequence_length:
        token_indices = token_indices[:max_sequence_length]
    else:
        token_indices += [padding_index] * (max_sequence_length - len(token_indices))

    essays_tensor.append(token_indices)
    print(f"token indices {k} appended")
    k += 1

# Convert the list to a numpy array
essays_tensor = np.array(essays_tensor)

# Save essays as a number representation in a tensor
torch.save(essays_tensor, 'essays_tensor.pt')

# Convert the list to a numpy array
essays_tensor = np.array(essays_tensor)

# Print statistics
print("Average length of essays:", average_length)
print("Minimum length of essays:", min_length)
print("Maximum length of essays:", max_sequence_length)

# Print the tensor representation of the first essay
print("Tensor representation of the first essay:")
print(essays_tensor[0])
# Out:
# token indices 0 appended
# token indices 1 appended
# token indices 2 appended
# token indices 3 appended
# token indices 4 appended
# token indices 5 appended
# token indices 6 appended
# token indices 7 appended
# token indices 8 appended
# token indices 9 appended
# token indices 10 appended
# token indices 11 appended
# token indices 12 appended
# token indices 13 appended
# token indices 14 appended
# token indices 15 appended
# token indices 16 appended
# token indices 17 appended
# token indices 18 appended
# token indices 19 appended
# token indices 20 appended
# token indices 21 appended
# token indices 22 appended
# token indices 23 appended
# token indices 24 appended
# token indices 25 appended
# token indices 26 appended
# token indices 27 appended
# token indices 28 appended
# token indices 29 appended
# token indices 30 appended
# token indices 31 appended
# token indices 32 appended
# token indices 33 appended
# token indices 34 appended
# token indices 35 appended
# token indices 36 appended
# token indices 37 appended
# token indices 38 appended
# token indices 39 appended
# token indices 40 appended
# token indices 41 appended
# token indices 42 appended
# token indices 43 appended
# token indices 44 appended
# token indices 45 appended
# token indices 46 appended
# token indices 47 appended
# token indices 48 appended
# token indices 49 appended
# token indices 50 appended
# token indices 51 appended
# token indices 52 appended
# token indices 53 appended
# token indices 54 appended
# token indices 55 appended
# token indices 56 appended
# token indices 57 appended
# token indices 58 appended
# token indices 59 appended
# token indices 60 appended
# token indices 61 appended
# token indices 62 appended
# token indices 63 appended
# token indices 64 appended
# token indices 65 appended
# token indices 66 appended
# token indices 67 appended
# token indices 68 appended
# token indices 69 appended
# token indices 70 appended
# token indices 71 appended
# token indices 72 appended
# token indices 73 appended
# token indices 74 appended
# token indices 75 appended
# token indices 76 appended
# token indices 77 appended
# token indices 78 appended
# token indices 79 appended
# token indices 80 appended
# token indices 81 appended
# token indices 82 appended
# token indices 83 appended
# token indices 84 appended
# token indices 85 appended
# token indices 86 appended
# token indices 87 appended
# token indices 88 appended
# token indices 89 appended
# token indices 90 appended
# token indices 91 appended
# token indices 92 appended
# token indices 93 appended
# token indices 94 appended
# token indices 95 appended
# token indices 96 appended
# token indices 97 appended
# token indices 98 appended
# token indices 99 appended
# token indices 100 appended
# token indices 101 appended
# token indices 102 appended
# token indices 103 appended
# token indices 104 appended
# token indices 105 appended
# token indices 106 appended
# token indices 107 appended
# token indices 108 appended
# token indices 109 appended
# token indices 110 appended
# token indices 111 appended
# token indices 112 appended
# token indices 113 appended
# token indices 114 appended
# token indices 115 appended
# token indices 116 appended
# token indices 117 appended
# token indices 118 appended
# token indices 119 appended
# token indices 120 appended
# token indices 121 appended
# token indices 122 appended
# token indices 123 appended
# token indices 124 appended
# token indices 125 appended
# token indices 126 appended
# token indices 127 appended
# token indices 128 appended
# token indices 129 appended
# token indices 130 appended
# token indices 131 appended
# token indices 132 appended
# token indices 133 appended
# token indices 134 appended
# token indices 135 appended
# token indices 136 appended
# token indices 137 appended
# token indices 138 appended
# token indices 139 appended
# token indices 140 appended
# token indices 141 appended
# token indices 142 appended
# token indices 143 appended
# token indices 144 appended
# token indices 145 appended
# token indices 146 appended
# token indices 147 appended
# token indices 148 appended
# token indices 149 appended
# token indices 150 appended
# token indices 151 appended
# token indices 152 appended
# token indices 153 appended
# token indices 154 appended
# token indices 155 appended
# token indices 156 appended
# token indices 157 appended
# token indices 158 appended
# token indices 159 appended
# token indices 160 appended
# token indices 161 appended
# token indices 162 appended
# token indices 163 appended
# token indices 164 appended
# token indices 165 appended
# token indices 166 appended
# token indices 167 appended
# token indices 168 appended
# token indices 169 appended
# token indices 170 appended
# token indices 171 appended
# token indices 172 appended
# token indices 173 appended
# token indices 174 appended
# token indices 175 appended
# token indices 176 appended
# token indices 177 appended
# token indices 178 appended
# token indices 179 appended
# token indices 180 appended
# token indices 181 appended
# token indices 182 appended
# token indices 183 appended
# token indices 184 appended
# token indices 185 appended
# token indices 186 appended
# token indices 187 appended
# token indices 188 appended
# token indices 189 appended
# token indices 190 appended
# token indices 191 appended
# token indices 192 appended
# token indices 193 appended
# token indices 194 appended
# token indices 195 appended
# token indices 196 appended
# token indices 197 appended
# token indices 198 appended
# token indices 199 appended
# token indices 200 appended
# token indices 201 appended
# token indices 202 appended
# token indices 203 appended
# token indices 204 appended
# token indices 205 appended
# token indices 206 appended
# token indices 207 appended
# token indices 208 appended
# token indices 209 appended
# token indices 210 appended
# token indices 211 appended
# token indices 212 appended
# token indices 213 appended
# token indices 214 appended
# token indices 215 appended
# token indices 216 appended
# token indices 217 appended
# token indices 218 appended
# token indices 219 appended
# token indices 220 appended
# token indices 221 appended
# token indices 222 appended
# token indices 223 appended
# token indices 224 appended
# token indices 225 appended
# token indices 226 appended
# token indices 227 appended
# token indices 228 appended
# token indices 229 appended
# token indices 230 appended
# token indices 231 appended
# token indices 232 appended
# token indices 233 appended
# token indices 234 appended
# token indices 235 appended
# token indices 236 appended
# token indices 237 appended
# token indices 238 appended
# token indices 239 appended
# token indices 240 appended
# token indices 241 appended
# token indices 242 appended
# token indices 243 appended
# token indices 244 appended
# token indices 245 appended
# token indices 246 appended
# token indices 247 appended
# token indices 248 appended
# token indices 249 appended
# token indices 250 appended
# token indices 251 appended
# token indices 252 appended
# token indices 253 appended
# token indices 254 appended
# token indices 255 appended
# token indices 256 appended
# token indices 257 appended
# token indices 258 appended
# token indices 259 appended
# token indices 260 appended
# token indices 261 appended
# token indices 262 appended
# token indices 263 appended
# token indices 264 appended
# token indices 265 appended
# token indices 266 appended
# token indices 267 appended
# token indices 268 appended
# token indices 269 appended
# token indices 270 appended
# token indices 271 appended
# token indices 272 appended
# token indices 273 appended
# token indices 274 appended
# token indices 275 appended
# token indices 276 appended
# token indices 277 appended
# token indices 278 appended
# token indices 279 appended
# token indices 280 appended
# token indices 281 appended
# token indices 282 appended
# token indices 283 appended
# token indices 284 appended
# token indices 285 appended
# token indices 286 appended
# token indices 287 appended
# token indices 288 appended
# token indices 289 appended
# token indices 290 appended
# token indices 291 appended
# token indices 292 appended
# token indices 293 appended
# token indices 294 appended
# token indices 295 appended
# token indices 296 appended
# token indices 297 appended
# token indices 298 appended
# token indices 299 appended
# token indices 300 appended
# token indices 301 appended
# token indices 302 appended
# token indices 303 appended
# token indices 304 appended
# token indices 305 appended
# token indices 306 appended
# token indices 307 appended
# token indices 308 appended
# token indices 309 appended
# token indices 310 appended
# token indices 311 appended
# token indices 312 appended
# token indices 313 appended
# token indices 314 appended
# token indices 315 appended
# token indices 316 appended
# token indices 317 appended
# token indices 318 appended
# token indices 319 appended
# token indices 320 appended
# token indices 321 appended
# token indices 322 appended
# token indices 323 appended
# token indices 324 appended
# token indices 325 appended
# token indices 326 appended
# token indices 327 appended
# token indices 328 appended
# token indices 329 appended
# token indices 330 appended
# token indices 331 appended
# token indices 332 appended
# token indices 333 appended
# token indices 334 appended
# token indices 335 appended
# token indices 336 appended
# token indices 337 appended
# token indices 338 appended
# token indices 339 appended
# token indices 340 appended
# token indices 341 appended
# token indices 342 appended
# token indices 343 appended
# token indices 344 appended
# token indices 345 appended
# token indices 346 appended
# token indices 347 appended
# token indices 348 appended
# token indices 349 appended
# token indices 350 appended
# token indices 351 appended
# token indices 352 appended
# token indices 353 appended
# token indices 354 appended
# token indices 355 appended
# token indices 356 appended
# token indices 357 appended
# token indices 358 appended
# token indices 359 appended
# token indices 360 appended
# token indices 361 appended
# token indices 362 appended
# token indices 363 appended
# token indices 364 appended
# token indices 365 appended
# token indices 366 appended
# token indices 367 appended
# token indices 368 appended
# token indices 369 appended
# token indices 370 appended
# token indices 371 appended
# token indices 372 appended
# token indices 373 appended
# token indices 374 appended
# token indices 375 appended
# token indices 376 appended
# token indices 377 appended
# token indices 378 appended
# token indices 379 appended
# token indices 380 appended
# token indices 381 appended
# token indices 382 appended
# token indices 383 appended
# token indices 384 appended
# token indices 385 appended
# token indices 386 appended
# token indices 387 appended
# token indices 388 appended
# token indices 389 appended
# token indices 390 appended
# token indices 391 appended
# token indices 392 appended
# token indices 393 appended
# token indices 394 appended
# token indices 395 appended
# token indices 396 appended
# token indices 397 appended
# token indices 398 appended
# token indices 399 appended
# token indices 400 appended
# token indices 401 appended
# token indices 402 appended
# token indices 403 appended
# token indices 404 appended
# token indices 405 appended
# token indices 406 appended
# token indices 407 appended
# token indices 408 appended
# token indices 409 appended
# token indices 410 appended
# token indices 411 appended
# token indices 412 appended
# token indices 413 appended
# token indices 414 appended
# token indices 415 appended
# token indices 416 appended
# token indices 417 appended
# token indices 418 appended
# token indices 419 appended
# token indices 420 appended
# token indices 421 appended
# token indices 422 appended
# token indices 423 appended
# token indices 424 appended
# token indices 425 appended
# token indices 426 appended
# token indices 427 appended
# token indices 428 appended
# token indices 429 appended
# token indices 430 appended
# token indices 431 appended
# token indices 432 appended
# token indices 433 appended
# token indices 434 appended
# token indices 435 appended
# token indices 436 appended
# token indices 437 appended
# token indices 438 appended
# token indices 439 appended
# token indices 440 appended
# token indices 441 appended
# token indices 442 appended
# token indices 443 appended
# token indices 444 appended
# token indices 445 appended
# token indices 446 appended
# token indices 447 appended
# token indices 448 appended
# token indices 449 appended
# token indices 450 appended
# token indices 451 appended
# token indices 452 appended
# token indices 453 appended
# token indices 454 appended
# token indices 455 appended
# token indices 456 appended
# token indices 457 appended
# token indices 458 appended
# token indices 459 appended
# token indices 460 appended
# token indices 461 appended
# token indices 462 appended
# token indices 463 appended
# token indices 464 appended
# token indices 465 appended
# token indices 466 appended
# token indices 467 appended
# token indices 468 appended
# token indices 469 appended
# token indices 470 appended
# token indices 471 appended
# token indices 472 appended
# token indices 473 appended
# token indices 474 appended
# token indices 475 appended
# token indices 476 appended
# token indices 477 appended
# token indices 478 appended
# token indices 479 appended
# token indices 480 appended
# token indices 481 appended
# token indices 482 appended
# token indices 483 appended
# token indices 484 appended
# token indices 485 appended
# token indices 486 appended
# token indices 487 appended
# token indices 488 appended
# token indices 489 appended
# token indices 490 appended
# token indices 491 appended
# token indices 492 appended
# token indices 493 appended
# token indices 494 appended
# token indices 495 appended
# token indices 496 appended
# token indices 497 appended
# token indices 498 appended
# token indices 499 appended
# token indices 500 appended
# token indices 501 appended
# token indices 502 appended
# token indices 503 appended
# token indices 504 appended
# token indices 505 appended
# token indices 506 appended
# token indices 507 appended
# token indices 508 appended
# token indices 509 appended
# token indices 510 appended
# token indices 511 appended
# token indices 512 appended
# token indices 513 appended
# token indices 514 appended
# token indices 515 appended
# token indices 516 appended
# token indices 517 appended
# token indices 518 appended
# token indices 519 appended
# token indices 520 appended
# token indices 521 appended
# token indices 522 appended
# token indices 523 appended
# token indices 524 appended
# token indices 525 appended
# token indices 526 appended
# token indices 527 appended
# token indices 528 appended
# token indices 529 appended
# token indices 530 appended
# token indices 531 appended
# token indices 532 appended
# token indices 533 appended
# token indices 534 appended
# token indices 535 appended
# token indices 536 appended
# token indices 537 appended
# token indices 538 appended
# token indices 539 appended
# token indices 540 appended
# token indices 541 appended
# token indices 542 appended
# token indices 543 appended
# token indices 544 appended
# token indices 545 appended
# token indices 546 appended
# token indices 547 appended
# token indices 548 appended
# token indices 549 appended
# token indices 550 appended
# token indices 551 appended
# token indices 552 appended
# token indices 553 appended
# token indices 554 appended
# token indices 555 appended
# token indices 556 appended
# token indices 557 appended
# token indices 558 appended
# token indices 559 appended
# token indices 560 appended
# token indices 561 appended
# token indices 562 appended
# token indices 563 appended
# token indices 564 appended
# token indices 565 appended
# token indices 566 appended
# token indices 567 appended
# token indices 568 appended
# token indices 569 appended
# token indices 570 appended
# token indices 571 appended
# token indices 572 appended
# token indices 573 appended
# token indices 574 appended
# token indices 575 appended
# token indices 576 appended
# token indices 577 appended
# token indices 578 appended
# token indices 579 appended
# token indices 580 appended
# token indices 581 appended
# token indices 582 appended
# token indices 583 appended
# token indices 584 appended
# token indices 585 appended
# token indices 586 appended
# token indices 587 appended
# token indices 588 appended
# token indices 589 appended
# token indices 590 appended
# token indices 591 appended
# token indices 592 appended
# token indices 593 appended
# token indices 594 appended
# token indices 595 appended
# token indices 596 appended
# token indices 597 appended
# token indices 598 appended
# token indices 599 appended
# token indices 600 appended
# token indices 601 appended
# token indices 602 appended
# token indices 603 appended
# token indices 604 appended
# token indices 605 appended
# token indices 606 appended
# token indices 607 appended
# token indices 608 appended
# token indices 609 appended
# token indices 610 appended
# token indices 611 appended
# token indices 612 appended
# token indices 613 appended
# token indices 614 appended
# token indices 615 appended
# token indices 616 appended
# token indices 617 appended
# token indices 618 appended
# token indices 619 appended
# token indices 620 appended
# token indices 621 appended
# token indices 622 appended
# token indices 623 appended
# token indices 624 appended
# token indices 625 appended
# token indices 626 appended
# token indices 627 appended
# token indices 628 appended
# token indices 629 appended
# token indices 630 appended
# token indices 631 appended
# token indices 632 appended
# token indices 633 appended
# token indices 634 appended
# token indices 635 appended
# token indices 636 appended
# token indices 637 appended
# token indices 638 appended
# token indices 639 appended
# token indices 640 appended
# token indices 641 appended
# token indices 642 appended
# token indices 643 appended
# token indices 644 appended
# token indices 645 appended
# token indices 646 appended
# token indices 647 appended
# token indices 648 appended
# token indices 649 appended
# token indices 650 appended
# token indices 651 appended
# token indices 652 appended
# token indices 653 appended
# token indices 654 appended
# token indices 655 appended
# token indices 656 appended
# token indices 657 appended
# token indices 658 appended
# token indices 659 appended
# token indices 660 appended
# token indices 661 appended
# token indices 662 appended
# token indices 663 appended
# token indices 664 appended
# token indices 665 appended
# token indices 666 appended
# token indices 667 appended
# token indices 668 appended
# token indices 669 appended
# token indices 670 appended
# token indices 671 appended
# token indices 672 appended
# token indices 673 appended
# token indices 674 appended
# token indices 675 appended
# token indices 676 appended
# token indices 677 appended
# token indices 678 appended
# token indices 679 appended
# token indices 680 appended
# token indices 681 appended
# token indices 682 appended
# token indices 683 appended
# token indices 684 appended
# token indices 685 appended
# token indices 686 appended
# token indices 687 appended
# token indices 688 appended
# token indices 689 appended
# token indices 690 appended
# token indices 691 appended
# token indices 692 appended
# token indices 693 appended
# token indices 694 appended
# token indices 695 appended
# token indices 696 appended
# token indices 697 appended
# token indices 698 appended
# token indices 699 appended
# token indices 700 appended
# token indices 701 appended
# token indices 702 appended
# token indices 703 appended
# token indices 704 appended
# token indices 705 appended
# token indices 706 appended
# token indices 707 appended
# token indices 708 appended
# token indices 709 appended
# token indices 710 appended
# token indices 711 appended
# token indices 712 appended
# token indices 713 appended
# token indices 714 appended
# token indices 715 appended
# token indices 716 appended
# token indices 717 appended
# token indices 718 appended
# token indices 719 appended
# token indices 720 appended
# token indices 721 appended
# token indices 722 appended
# token indices 723 appended
# token indices 724 appended
# token indices 725 appended
# token indices 726 appended
# token indices 727 appended
# token indices 728 appended
# token indices 729 appended
# token indices 730 appended
# token indices 731 appended
# token indices 732 appended
# token indices 733 appended
# token indices 734 appended
# token indices 735 appended
# token indices 736 appended
# token indices 737 appended
# token indices 738 appended
# token indices 739 appended
# token indices 740 appended
# token indices 741 appended
# token indices 742 appended
# token indices 743 appended
# token indices 744 appended
# token indices 745 appended
# token indices 746 appended
# token indices 747 appended
# token indices 748 appended
# token indices 749 appended
# token indices 750 appended
# token indices 751 appended
# token indices 752 appended
# token indices 753 appended
# token indices 754 appended
# token indices 755 appended
# token indices 756 appended
# token indices 757 appended
# token indices 758 appended
# token indices 759 appended
# token indices 760 appended
# token indices 761 appended
# token indices 762 appended
# token indices 763 appended
# token indices 764 appended
# token indices 765 appended
# token indices 766 appended
# token indices 767 appended
# token indices 768 appended
# token indices 769 appended
# token indices 770 appended
# token indices 771 appended
# token indices 772 appended
# token indices 773 appended
# token indices 774 appended
# token indices 775 appended
# token indices 776 appended
# token indices 777 appended
# token indices 778 appended
# token indices 779 appended
# token indices 780 appended
# token indices 781 appended
# token indices 782 appended
# token indices 783 appended
# token indices 784 appended
# token indices 785 appended
# token indices 786 appended
# token indices 787 appended
# token indices 788 appended
# token indices 789 appended
# token indices 790 appended
# token indices 791 appended
# token indices 792 appended
# token indices 793 appended
# token indices 794 appended
# token indices 795 appended
# token indices 796 appended
# token indices 797 appended
# token indices 798 appended
# token indices 799 appended
# token indices 800 appended
# token indices 801 appended
# token indices 802 appended
# token indices 803 appended
# token indices 804 appended
# token indices 805 appended
# token indices 806 appended
# token indices 807 appended
# token indices 808 appended
# token indices 809 appended
# token indices 810 appended
# token indices 811 appended
# token indices 812 appended
# token indices 813 appended
# token indices 814 appended
# token indices 815 appended
# token indices 816 appended
# token indices 817 appended
# token indices 818 appended
# token indices 819 appended
# token indices 820 appended
# token indices 821 appended
# token indices 822 appended
# token indices 823 appended
# token indices 824 appended
# token indices 825 appended
# token indices 826 appended
# token indices 827 appended
# token indices 828 appended
# token indices 829 appended
# token indices 830 appended
# token indices 831 appended
# token indices 832 appended
# token indices 833 appended
# token indices 834 appended
# token indices 835 appended
# token indices 836 appended
# token indices 837 appended
# token indices 838 appended
# token indices 839 appended
# token indices 840 appended
# token indices 841 appended
# token indices 842 appended
# token indices 843 appended
# token indices 844 appended
# token indices 845 appended
# token indices 846 appended
# token indices 847 appended
# token indices 848 appended
# token indices 849 appended
# token indices 850 appended
# token indices 851 appended
# token indices 852 appended
# token indices 853 appended
# token indices 854 appended
# token indices 855 appended
# token indices 856 appended
# token indices 857 appended
# token indices 858 appended
# token indices 859 appended
# token indices 860 appended
# token indices 861 appended
# token indices 862 appended
# token indices 863 appended
# token indices 864 appended
# token indices 865 appended
# token indices 866 appended
# token indices 867 appended
# token indices 868 appended
# token indices 869 appended
# token indices 870 appended
# token indices 871 appended
# token indices 872 appended
# token indices 873 appended
# token indices 874 appended
# token indices 875 appended
# token indices 876 appended
# token indices 877 appended
# token indices 878 appended
# token indices 879 appended
# token indices 880 appended
# token indices 881 appended
# token indices 882 appended
# token indices 883 appended
# token indices 884 appended
# token indices 885 appended
# token indices 886 appended
# token indices 887 appended
# token indices 888 appended
# token indices 889 appended
# token indices 890 appended
# token indices 891 appended
# token indices 892 appended
# token indices 893 appended
# token indices 894 appended
# token indices 895 appended
# token indices 896 appended
# token indices 897 appended
# token indices 898 appended
# token indices 899 appended
# token indices 900 appended
# token indices 901 appended
# token indices 902 appended
# token indices 903 appended
# token indices 904 appended
# token indices 905 appended
# token indices 906 appended
# token indices 907 appended
# token indices 908 appended
# token indices 909 appended
# token indices 910 appended
# token indices 911 appended
# token indices 912 appended
# token indices 913 appended
# token indices 914 appended
# token indices 915 appended
# token indices 916 appended
# token indices 917 appended
# token indices 918 appended
# token indices 919 appended
# token indices 920 appended
# token indices 921 appended
# token indices 922 appended
# token indices 923 appended
# token indices 924 appended
# token indices 925 appended
# token indices 926 appended
# token indices 927 appended
# token indices 928 appended
# token indices 929 appended
# token indices 930 appended
# token indices 931 appended
# token indices 932 appended
# token indices 933 appended
# token indices 934 appended
# token indices 935 appended
# token indices 936 appended
# token indices 937 appended
# token indices 938 appended
# token indices 939 appended
# token indices 940 appended
# token indices 941 appended
# token indices 942 appended
# token indices 943 appended
# token indices 944 appended
# token indices 945 appended
# token indices 946 appended
# token indices 947 appended
# token indices 948 appended
# token indices 949 appended
# token indices 950 appended
# token indices 951 appended
# token indices 952 appended
# token indices 953 appended
# token indices 954 appended
# token indices 955 appended
# token indices 956 appended
# token indices 957 appended
# token indices 958 appended
# token indices 959 appended
# token indices 960 appended
# token indices 961 appended
# token indices 962 appended
# token indices 963 appended
# token indices 964 appended
# token indices 965 appended
# token indices 966 appended
# token indices 967 appended
# token indices 968 appended
# token indices 969 appended
# token indices 970 appended
# token indices 971 appended
# token indices 972 appended
# token indices 973 appended
# token indices 974 appended
# token indices 975 appended
# token indices 976 appended
# token indices 977 appended
# token indices 978 appended
# token indices 979 appended
# token indices 980 appended
# token indices 981 appended
# token indices 982 appended
# token indices 983 appended
# token indices 984 appended
# token indices 985 appended
# token indices 986 appended
# token indices 987 appended
# token indices 988 appended
# token indices 989 appended
# token indices 990 appended
# token indices 991 appended
# token indices 992 appended
# token indices 993 appended
# token indices 994 appended
# token indices 995 appended
# token indices 996 appended
# token indices 997 appended
# token indices 998 appended
# token indices 999 appended
# token indices 1000 appended
# token indices 1001 appended
# token indices 1002 appended
# token indices 1003 appended
# token indices 1004 appended
# token indices 1005 appended
# token indices 1006 appended
# token indices 1007 appended
# token indices 1008 appended
# token indices 1009 appended
# token indices 1010 appended
# token indices 1011 appended
# token indices 1012 appended
# token indices 1013 appended
# token indices 1014 appended
# token indices 1015 appended
# token indices 1016 appended
# token indices 1017 appended
# token indices 1018 appended
# token indices 1019 appended
# token indices 1020 appended
# token indices 1021 appended
# token indices 1022 appended
# token indices 1023 appended
# token indices 1024 appended
# token indices 1025 appended
# token indices 1026 appended
# token indices 1027 appended
# token indices 1028 appended
# token indices 1029 appended
# token indices 1030 appended
# token indices 1031 appended
# token indices 1032 appended
# token indices 1033 appended
# token indices 1034 appended
# token indices 1035 appended
# token indices 1036 appended
# token indices 1037 appended
# token indices 1038 appended
# token indices 1039 appended
# token indices 1040 appended
# token indices 1041 appended
# token indices 1042 appended
# token indices 1043 appended
# token indices 1044 appended
# token indices 1045 appended
# token indices 1046 appended
# token indices 1047 appended
# token indices 1048 appended
# token indices 1049 appended
# token indices 1050 appended
# token indices 1051 appended
# token indices 1052 appended
# token indices 1053 appended
# token indices 1054 appended
# token indices 1055 appended
# token indices 1056 appended
# token indices 1057 appended
# token indices 1058 appended
# token indices 1059 appended
# token indices 1060 appended
# token indices 1061 appended
# token indices 1062 appended
# token indices 1063 appended
# token indices 1064 appended
# token indices 1065 appended
# token indices 1066 appended
# token indices 1067 appended
# token indices 1068 appended
# token indices 1069 appended
# token indices 1070 appended
# token indices 1071 appended
# token indices 1072 appended
# token indices 1073 appended
# token indices 1074 appended
# token indices 1075 appended
# token indices 1076 appended
# token indices 1077 appended
# token indices 1078 appended
# token indices 1079 appended
# token indices 1080 appended
# token indices 1081 appended
# token indices 1082 appended
# token indices 1083 appended
# token indices 1084 appended
# token indices 1085 appended
# token indices 1086 appended
# token indices 1087 appended
# token indices 1088 appended
# token indices 1089 appended
# token indices 1090 appended
# token indices 1091 appended
# token indices 1092 appended
# token indices 1093 appended
# token indices 1094 appended
# token indices 1095 appended
# token indices 1096 appended
# token indices 1097 appended
# token indices 1098 appended
# token indices 1099 appended
# token indices 1100 appended
# token indices 1101 appended
# token indices 1102 appended
# token indices 1103 appended
# token indices 1104 appended
# token indices 1105 appended
# token indices 1106 appended
# token indices 1107 appended
# token indices 1108 appended
# token indices 1109 appended
# token indices 1110 appended
# token indices 1111 appended
# token indices 1112 appended
# token indices 1113 appended
# token indices 1114 appended
# token indices 1115 appended
# token indices 1116 appended
# token indices 1117 appended
# token indices 1118 appended
# token indices 1119 appended
# token indices 1120 appended
# token indices 1121 appended
# token indices 1122 appended
# token indices 1123 appended
# token indices 1124 appended
# token indices 1125 appended
# token indices 1126 appended
# token indices 1127 appended
# token indices 1128 appended
# token indices 1129 appended
# token indices 1130 appended
# token indices 1131 appended
# token indices 1132 appended
# token indices 1133 appended
# token indices 1134 appended
# token indices 1135 appended
# token indices 1136 appended
# token indices 1137 appended
# token indices 1138 appended
# token indices 1139 appended
# token indices 1140 appended
# token indices 1141 appended
# token indices 1142 appended
# token indices 1143 appended
# token indices 1144 appended
# token indices 1145 appended
# token indices 1146 appended
# token indices 1147 appended
# token indices 1148 appended
# token indices 1149 appended
# token indices 1150 appended
# token indices 1151 appended
# token indices 1152 appended
# token indices 1153 appended
# token indices 1154 appended
# token indices 1155 appended
# token indices 1156 appended
# token indices 1157 appended
# token indices 1158 appended
# token indices 1159 appended
# token indices 1160 appended
# token indices 1161 appended
# token indices 1162 appended
# token indices 1163 appended
# token indices 1164 appended
# token indices 1165 appended
# token indices 1166 appended
# token indices 1167 appended
# token indices 1168 appended
# token indices 1169 appended
# token indices 1170 appended
# token indices 1171 appended
# token indices 1172 appended
# token indices 1173 appended
# token indices 1174 appended
# token indices 1175 appended
# token indices 1176 appended
# token indices 1177 appended
# token indices 1178 appended
# token indices 1179 appended
# token indices 1180 appended
# token indices 1181 appended
# token indices 1182 appended
# token indices 1183 appended
# token indices 1184 appended
# token indices 1185 appended
# token indices 1186 appended
# token indices 1187 appended
# token indices 1188 appended
# token indices 1189 appended
# token indices 1190 appended
# token indices 1191 appended
# token indices 1192 appended
# token indices 1193 appended
# token indices 1194 appended
# token indices 1195 appended
# token indices 1196 appended
# token indices 1197 appended
# token indices 1198 appended
# token indices 1199 appended
# token indices 1200 appended
# token indices 1201 appended
# token indices 1202 appended
# token indices 1203 appended
# token indices 1204 appended
# token indices 1205 appended
# token indices 1206 appended
# token indices 1207 appended
# token indices 1208 appended
# token indices 1209 appended
# token indices 1210 appended
# token indices 1211 appended
# token indices 1212 appended
# token indices 1213 appended
# token indices 1214 appended
# token indices 1215 appended
# token indices 1216 appended
# token indices 1217 appended
# token indices 1218 appended
# token indices 1219 appended
# token indices 1220 appended
# token indices 1221 appended
# token indices 1222 appended
# token indices 1223 appended
# token indices 1224 appended
# token indices 1225 appended
# token indices 1226 appended
# token indices 1227 appended
# token indices 1228 appended
# token indices 1229 appended
# token indices 1230 appended
# token indices 1231 appended
# token indices 1232 appended
# token indices 1233 appended
# token indices 1234 appended
# token indices 1235 appended
# token indices 1236 appended
# token indices 1237 appended
# token indices 1238 appended
# token indices 1239 appended
# token indices 1240 appended
# token indices 1241 appended
# token indices 1242 appended
# token indices 1243 appended
# token indices 1244 appended
# token indices 1245 appended
# token indices 1246 appended
# token indices 1247 appended
# token indices 1248 appended
# token indices 1249 appended
# token indices 1250 appended
# token indices 1251 appended
# token indices 1252 appended
# token indices 1253 appended
# token indices 1254 appended
# token indices 1255 appended
# token indices 1256 appended
# token indices 1257 appended
# token indices 1258 appended
# token indices 1259 appended
# token indices 1260 appended
# token indices 1261 appended
# token indices 1262 appended
# token indices 1263 appended
# token indices 1264 appended
# token indices 1265 appended
# token indices 1266 appended
# token indices 1267 appended
# token indices 1268 appended
# token indices 1269 appended
# token indices 1270 appended
# token indices 1271 appended
# token indices 1272 appended
# token indices 1273 appended
# token indices 1274 appended
# token indices 1275 appended
# token indices 1276 appended
# token indices 1277 appended
# token indices 1278 appended
# token indices 1279 appended
# token indices 1280 appended
# token indices 1281 appended
# token indices 1282 appended
# token indices 1283 appended
# token indices 1284 appended
# token indices 1285 appended
# token indices 1286 appended
# token indices 1287 appended
# token indices 1288 appended
# token indices 1289 appended
# token indices 1290 appended
# token indices 1291 appended
# token indices 1292 appended
# token indices 1293 appended
# token indices 1294 appended
# token indices 1295 appended
# token indices 1296 appended
# token indices 1297 appended
# token indices 1298 appended
# token indices 1299 appended
# token indices 1300 appended
# token indices 1301 appended
# token indices 1302 appended
# token indices 1303 appended
# token indices 1304 appended
# token indices 1305 appended
# token indices 1306 appended
# token indices 1307 appended
# token indices 1308 appended
# token indices 1309 appended
# token indices 1310 appended
# token indices 1311 appended
# token indices 1312 appended
# token indices 1313 appended
# token indices 1314 appended
# token indices 1315 appended
# token indices 1316 appended
# token indices 1317 appended
# token indices 1318 appended
# token indices 1319 appended
# token indices 1320 appended
# token indices 1321 appended
# token indices 1322 appended
# token indices 1323 appended
# token indices 1324 appended
# token indices 1325 appended
# token indices 1326 appended
# token indices 1327 appended
# token indices 1328 appended
# token indices 1329 appended
# token indices 1330 appended
# token indices 1331 appended
# token indices 1332 appended
# token indices 1333 appended
# token indices 1334 appended
# token indices 1335 appended
# token indices 1336 appended
# token indices 1337 appended
# token indices 1338 appended
# token indices 1339 appended
# token indices 1340 appended
# token indices 1341 appended
# token indices 1342 appended
# token indices 1343 appended
# token indices 1344 appended
# token indices 1345 appended
# token indices 1346 appended
# token indices 1347 appended
# token indices 1348 appended
# token indices 1349 appended
# token indices 1350 appended
# token indices 1351 appended
# token indices 1352 appended
# token indices 1353 appended
# token indices 1354 appended
# token indices 1355 appended
# token indices 1356 appended
# token indices 1357 appended
# token indices 1358 appended
# token indices 1359 appended
# token indices 1360 appended
# token indices 1361 appended
# token indices 1362 appended
# token indices 1363 appended
# token indices 1364 appended
# token indices 1365 appended
# token indices 1366 appended
# token indices 1367 appended
# token indices 1368 appended
# token indices 1369 appended
# token indices 1370 appended
# token indices 1371 appended
# token indices 1372 appended
# token indices 1373 appended
# token indices 1374 appended
# token indices 1375 appended
# token indices 1376 appended
# token indices 1377 appended
# token indices 1378 appended
# token indices 1379 appended
# token indices 1380 appended
# token indices 1381 appended
# token indices 1382 appended
# token indices 1383 appended
# token indices 1384 appended
# token indices 1385 appended
# token indices 1386 appended
# token indices 1387 appended
# token indices 1388 appended
# token indices 1389 appended
# token indices 1390 appended
# token indices 1391 appended
# token indices 1392 appended
# token indices 1393 appended
# token indices 1394 appended
# token indices 1395 appended
# token indices 1396 appended
# token indices 1397 appended
# token indices 1398 appended
# token indices 1399 appended
# token indices 1400 appended
# token indices 1401 appended
# token indices 1402 appended
# token indices 1403 appended
# token indices 1404 appended
# token indices 1405 appended
# token indices 1406 appended
# token indices 1407 appended
# token indices 1408 appended
# token indices 1409 appended
# token indices 1410 appended
# token indices 1411 appended
# token indices 1412 appended
# token indices 1413 appended
# token indices 1414 appended
# token indices 1415 appended
# token indices 1416 appended
# token indices 1417 appended
# token indices 1418 appended
# token indices 1419 appended
# token indices 1420 appended
# token indices 1421 appended
# token indices 1422 appended
# token indices 1423 appended
# token indices 1424 appended
# token indices 1425 appended
# token indices 1426 appended
# token indices 1427 appended
# token indices 1428 appended
# token indices 1429 appended
# token indices 1430 appended
# token indices 1431 appended
# token indices 1432 appended
# token indices 1433 appended
# token indices 1434 appended
# token indices 1435 appended
# token indices 1436 appended
# token indices 1437 appended
# token indices 1438 appended
# token indices 1439 appended
# token indices 1440 appended
# token indices 1441 appended
# token indices 1442 appended
# token indices 1443 appended
# token indices 1444 appended
# token indices 1445 appended
# token indices 1446 appended
# token indices 1447 appended
# token indices 1448 appended
# token indices 1449 appended
# token indices 1450 appended
# token indices 1451 appended
# token indices 1452 appended
# token indices 1453 appended
# token indices 1454 appended
# token indices 1455 appended
# token indices 1456 appended
# token indices 1457 appended
# token indices 1458 appended
# token indices 1459 appended
# token indices 1460 appended
# token indices 1461 appended
# token indices 1462 appended
# token indices 1463 appended
# token indices 1464 appended
# token indices 1465 appended
# token indices 1466 appended
# token indices 1467 appended
# token indices 1468 appended
# token indices 1469 appended
# token indices 1470 appended
# token indices 1471 appended
# token indices 1472 appended
# token indices 1473 appended
# token indices 1474 appended
# token indices 1475 appended
# token indices 1476 appended
# token indices 1477 appended
# token indices 1478 appended
# token indices 1479 appended
# token indices 1480 appended
# token indices 1481 appended
# token indices 1482 appended
# token indices 1483 appended
# token indices 1484 appended
# token indices 1485 appended
# token indices 1486 appended
# token indices 1487 appended
# token indices 1488 appended
# token indices 1489 appended
# token indices 1490 appended
# token indices 1491 appended
# token indices 1492 appended
# token indices 1493 appended
# token indices 1494 appended
# token indices 1495 appended
# token indices 1496 appended
# token indices 1497 appended
# token indices 1498 appended
# token indices 1499 appended
# token indices 1500 appended
# token indices 1501 appended
# token indices 1502 appended
# token indices 1503 appended
# token indices 1504 appended
# token indices 1505 appended
# token indices 1506 appended
# token indices 1507 appended
# token indices 1508 appended
# token indices 1509 appended
# token indices 1510 appended
# token indices 1511 appended
# token indices 1512 appended
# token indices 1513 appended
# token indices 1514 appended
# token indices 1515 appended
# token indices 1516 appended
# token indices 1517 appended
# token indices 1518 appended
# token indices 1519 appended
# token indices 1520 appended
# token indices 1521 appended
# token indices 1522 appended
# token indices 1523 appended
# token indices 1524 appended
# token indices 1525 appended
# token indices 1526 appended
# token indices 1527 appended
# token indices 1528 appended
# token indices 1529 appended
# token indices 1530 appended
# token indices 1531 appended
# token indices 1532 appended
# token indices 1533 appended
# token indices 1534 appended
# token indices 1535 appended
# token indices 1536 appended
# token indices 1537 appended
# token indices 1538 appended
# token indices 1539 appended
# token indices 1540 appended
# token indices 1541 appended
# token indices 1542 appended
# token indices 1543 appended
# token indices 1544 appended
# token indices 1545 appended
# token indices 1546 appended
# token indices 1547 appended
# token indices 1548 appended
# token indices 1549 appended
# token indices 1550 appended
# token indices 1551 appended
# token indices 1552 appended
# token indices 1553 appended
# token indices 1554 appended
# token indices 1555 appended
# token indices 1556 appended
# token indices 1557 appended
# token indices 1558 appended
# token indices 1559 appended
# token indices 1560 appended
# token indices 1561 appended
# token indices 1562 appended
# token indices 1563 appended
# token indices 1564 appended
# token indices 1565 appended
# token indices 1566 appended
# token indices 1567 appended
# token indices 1568 appended
# token indices 1569 appended
# token indices 1570 appended
# token indices 1571 appended
# token indices 1572 appended
# token indices 1573 appended
# token indices 1574 appended
# token indices 1575 appended
# token indices 1576 appended
# token indices 1577 appended
# token indices 1578 appended
# token indices 1579 appended
# token indices 1580 appended
# token indices 1581 appended
# token indices 1582 appended
# token indices 1583 appended
# token indices 1584 appended
# token indices 1585 appended
# token indices 1586 appended
# token indices 1587 appended
# token indices 1588 appended
# token indices 1589 appended
# token indices 1590 appended
# token indices 1591 appended
# token indices 1592 appended
# token indices 1593 appended
# token indices 1594 appended
# token indices 1595 appended
# token indices 1596 appended
# token indices 1597 appended
# token indices 1598 appended
# token indices 1599 appended
# token indices 1600 appended
# token indices 1601 appended
# token indices 1602 appended
# token indices 1603 appended
# token indices 1604 appended
# token indices 1605 appended
# token indices 1606 appended
# token indices 1607 appended
# token indices 1608 appended
# token indices 1609 appended
# token indices 1610 appended
# token indices 1611 appended
# token indices 1612 appended
# token indices 1613 appended
# token indices 1614 appended
# token indices 1615 appended
# token indices 1616 appended
# token indices 1617 appended
# token indices 1618 appended
# token indices 1619 appended
# token indices 1620 appended
# token indices 1621 appended
# token indices 1622 appended
# token indices 1623 appended
# token indices 1624 appended
# token indices 1625 appended
# token indices 1626 appended
# token indices 1627 appended
# token indices 1628 appended
# token indices 1629 appended
# token indices 1630 appended
# token indices 1631 appended
# token indices 1632 appended
# token indices 1633 appended
# token indices 1634 appended
# token indices 1635 appended
# token indices 1636 appended
# token indices 1637 appended
# token indices 1638 appended
# token indices 1639 appended
# token indices 1640 appended
# token indices 1641 appended
# token indices 1642 appended
# token indices 1643 appended
# token indices 1644 appended
# token indices 1645 appended
# token indices 1646 appended
# token indices 1647 appended
# token indices 1648 appended
# token indices 1649 appended
# token indices 1650 appended
# token indices 1651 appended
# token indices 1652 appended
# token indices 1653 appended
# token indices 1654 appended
# token indices 1655 appended
# token indices 1656 appended
# token indices 1657 appended
# token indices 1658 appended
# token indices 1659 appended
# token indices 1660 appended
# token indices 1661 appended
# token indices 1662 appended
# token indices 1663 appended
# token indices 1664 appended
# token indices 1665 appended
# token indices 1666 appended
# token indices 1667 appended
# token indices 1668 appended
# token indices 1669 appended
# token indices 1670 appended
# token indices 1671 appended
# token indices 1672 appended
# token indices 1673 appended
# token indices 1674 appended
# token indices 1675 appended
# token indices 1676 appended
# token indices 1677 appended
# token indices 1678 appended
# token indices 1679 appended
# token indices 1680 appended
# token indices 1681 appended
# token indices 1682 appended
# token indices 1683 appended
# token indices 1684 appended
# token indices 1685 appended
# token indices 1686 appended
# token indices 1687 appended
# token indices 1688 appended
# token indices 1689 appended
# token indices 1690 appended
# token indices 1691 appended
# token indices 1692 appended
# token indices 1693 appended
# token indices 1694 appended
# token indices 1695 appended
# token indices 1696 appended
# token indices 1697 appended
# token indices 1698 appended
# token indices 1699 appended
# token indices 1700 appended
# token indices 1701 appended
# token indices 1702 appended
# token indices 1703 appended
# token indices 1704 appended
# token indices 1705 appended
# token indices 1706 appended
# token indices 1707 appended
# token indices 1708 appended
# token indices 1709 appended
# token indices 1710 appended
# token indices 1711 appended
# token indices 1712 appended
# token indices 1713 appended
# token indices 1714 appended
# token indices 1715 appended
# token indices 1716 appended
# token indices 1717 appended
# token indices 1718 appended
# token indices 1719 appended
# token indices 1720 appended
# token indices 1721 appended
# token indices 1722 appended
# token indices 1723 appended
# token indices 1724 appended
# token indices 1725 appended
# token indices 1726 appended
# token indices 1727 appended
# token indices 1728 appended
# token indices 1729 appended
# token indices 1730 appended
# token indices 1731 appended
# token indices 1732 appended
# token indices 1733 appended
# token indices 1734 appended
# token indices 1735 appended
# token indices 1736 appended
# token indices 1737 appended
# token indices 1738 appended
# token indices 1739 appended
# token indices 1740 appended
# token indices 1741 appended
# token indices 1742 appended
# token indices 1743 appended
# token indices 1744 appended
# token indices 1745 appended
# token indices 1746 appended
# token indices 1747 appended
# token indices 1748 appended
# token indices 1749 appended
# token indices 1750 appended
# token indices 1751 appended
# token indices 1752 appended
# ...
# token indices 28605 appended
# token indices 28606 appended
# token indices 28607 appended
# token indices 28608 appended
# token indices 28609 appended
# token indices 28610 appended
# token indices 28611 appended
# token indices 28612 appended
# token indices 28613 appended
# token indices 28614 appended
# token indices 28615 appended
# token indices 28616 appended
# token indices 28617 appended
# token indices 28618 appended
# token indices 28619 appended
# token indices 28620 appended
# token indices 28621 appended
# token indices 28622 appended
# token indices 28623 appended
# token indices 28624 appended
# token indices 28625 appended
# token indices 28626 appended
# token indices 28627 appended
# token indices 28628 appended
# token indices 28629 appended
# token indices 28630 appended
# token indices 28631 appended
# token indices 28632 appended
# token indices 28633 appended
# token indices 28634 appended
# token indices 28635 appended
# token indices 28636 appended
# token indices 28637 appended
# token indices 28638 appended
# token indices 28639 appended
# token indices 28640 appended
# token indices 28641 appended
# token indices 28642 appended
# token indices 28643 appended
# token indices 28644 appended
# token indices 28645 appended
# token indices 28646 appended
# token indices 28647 appended
# token indices 28648 appended
# token indices 28649 appended
# token indices 28650 appended
# token indices 28651 appended
# token indices 28652 appended
# token indices 28653 appended
# token indices 28654 appended
# token indices 28655 appended
# token indices 28656 appended
# token indices 28657 appended
# token indices 28658 appended
# token indices 28659 appended
# token indices 28660 appended
# token indices 28661 appended
# token indices 28662 appended
# token indices 28663 appended
# token indices 28664 appended
# token indices 28665 appended
# token indices 28666 appended
# token indices 28667 appended
# token indices 28668 appended
# token indices 28669 appended
# token indices 28670 appended
# token indices 28671 appended
# token indices 28672 appended
# token indices 28673 appended
# token indices 28674 appended
# token indices 28675 appended
# token indices 28676 appended
# token indices 28677 appended
# token indices 28678 appended
# token indices 28679 appended
# token indices 28680 appended
# token indices 28681 appended
# token indices 28682 appended
# token indices 28683 appended
# token indices 28684 appended
# token indices 28685 appended
# token indices 28686 appended
# token indices 28687 appended
# token indices 28688 appended
# token indices 28689 appended
# token indices 28690 appended
# token indices 28691 appended
# token indices 28692 appended
# token indices 28693 appended
# token indices 28694 appended
# token indices 28695 appended
# token indices 28696 appended
# token indices 28697 appended
# token indices 28698 appended
# token indices 28699 appended
# token indices 28700 appended
# token indices 28701 appended
# token indices 28702 appended
# token indices 28703 appended
# token indices 28704 appended
# token indices 28705 appended
# token indices 28706 appended
# token indices 28707 appended
# token indices 28708 appended
# token indices 28709 appended
# token indices 28710 appended
# token indices 28711 appended
# token indices 28712 appended
# token indices 28713 appended
# token indices 28714 appended
# token indices 28715 appended
# token indices 28716 appended
# token indices 28717 appended
# token indices 28718 appended
# token indices 28719 appended
# token indices 28720 appended
# token indices 28721 appended
# token indices 28722 appended
# token indices 28723 appended
# token indices 28724 appended
# token indices 28725 appended
# token indices 28726 appended
# token indices 28727 appended
# token indices 28728 appended
# token indices 28729 appended
# token indices 28730 appended
# token indices 28731 appended
# token indices 28732 appended
# token indices 28733 appended
# token indices 28734 appended
# token indices 28735 appended
# token indices 28736 appended
# token indices 28737 appended
# token indices 28738 appended
# token indices 28739 appended
# token indices 28740 appended
# token indices 28741 appended
# token indices 28742 appended
# token indices 28743 appended
# token indices 28744 appended
# token indices 28745 appended
# token indices 28746 appended
# token indices 28747 appended
# token indices 28748 appended
# token indices 28749 appended
# token indices 28750 appended
# token indices 28751 appended
# token indices 28752 appended
# token indices 28753 appended
# token indices 28754 appended
# token indices 28755 appended
# token indices 28756 appended
# token indices 28757 appended
# token indices 28758 appended
# token indices 28759 appended
# token indices 28760 appended
# token indices 28761 appended
# token indices 28762 appended
# token indices 28763 appended
# token indices 28764 appended
# token indices 28765 appended
# token indices 28766 appended
# token indices 28767 appended
# token indices 28768 appended
# token indices 28769 appended
# token indices 28770 appended
# token indices 28771 appended
# token indices 28772 appended
# token indices 28773 appended
# token indices 28774 appended
# token indices 28775 appended
# token indices 28776 appended
# token indices 28777 appended
# token indices 28778 appended
# token indices 28779 appended
# token indices 28780 appended
# token indices 28781 appended
# token indices 28782 appended
# token indices 28783 appended
# token indices 28784 appended
# token indices 28785 appended
# token indices 28786 appended
# token indices 28787 appended
# token indices 28788 appended
# token indices 28789 appended
# token indices 28790 appended
# token indices 28791 appended
# token indices 28792 appended
# token indices 28793 appended
# token indices 28794 appended
# token indices 28795 appended
# token indices 28796 appended
# token indices 28797 appended
# token indices 28798 appended
# token indices 28799 appended
# token indices 28800 appended
# token indices 28801 appended
# token indices 28802 appended
# token indices 28803 appended
# token indices 28804 appended
# token indices 28805 appended
# token indices 28806 appended
# token indices 28807 appended
# token indices 28808 appended
# token indices 28809 appended
# token indices 28810 appended
# token indices 28811 appended
# token indices 28812 appended
# token indices 28813 appended
# token indices 28814 appended
# token indices 28815 appended
# token indices 28816 appended
# token indices 28817 appended
# token indices 28818 appended
# token indices 28819 appended
# token indices 28820 appended
# token indices 28821 appended
# token indices 28822 appended
# token indices 28823 appended
# token indices 28824 appended
# token indices 28825 appended
# token indices 28826 appended
# token indices 28827 appended
# token indices 28828 appended
# token indices 28829 appended
# token indices 28830 appended
# token indices 28831 appended
# token indices 28832 appended
# token indices 28833 appended
# token indices 28834 appended
# token indices 28835 appended
# token indices 28836 appended
# token indices 28837 appended
# token indices 28838 appended
# token indices 28839 appended
# token indices 28840 appended
# token indices 28841 appended
# token indices 28842 appended
# token indices 28843 appended
# token indices 28844 appended
# token indices 28845 appended
# token indices 28846 appended
# token indices 28847 appended
# token indices 28848 appended
# token indices 28849 appended
# token indices 28850 appended
# token indices 28851 appended
# token indices 28852 appended
# token indices 28853 appended
# token indices 28854 appended
# token indices 28855 appended
# token indices 28856 appended
# token indices 28857 appended
# token indices 28858 appended
# token indices 28859 appended
# token indices 28860 appended
# token indices 28861 appended
# token indices 28862 appended
# token indices 28863 appended
# token indices 28864 appended
# token indices 28865 appended
# token indices 28866 appended
# token indices 28867 appended
# token indices 28868 appended
# token indices 28869 appended
# token indices 28870 appended
# token indices 28871 appended
# token indices 28872 appended
# token indices 28873 appended
# token indices 28874 appended
# token indices 28875 appended
# token indices 28876 appended
# token indices 28877 appended
# token indices 28878 appended
# token indices 28879 appended
# token indices 28880 appended
# token indices 28881 appended
# token indices 28882 appended
# token indices 28883 appended
# token indices 28884 appended
# token indices 28885 appended
# token indices 28886 appended
# token indices 28887 appended
# token indices 28888 appended
# token indices 28889 appended
# token indices 28890 appended
# token indices 28891 appended
# token indices 28892 appended
# token indices 28893 appended
# token indices 28894 appended
# token indices 28895 appended
# token indices 28896 appended
# token indices 28897 appended
# token indices 28898 appended
# token indices 28899 appended
# token indices 28900 appended
# token indices 28901 appended
# token indices 28902 appended
# token indices 28903 appended
# token indices 28904 appended
# token indices 28905 appended
# token indices 28906 appended
# token indices 28907 appended
# token indices 28908 appended
# token indices 28909 appended
# token indices 28910 appended
# token indices 28911 appended
# token indices 28912 appended
# token indices 28913 appended
# token indices 28914 appended
# token indices 28915 appended
# token indices 28916 appended
# token indices 28917 appended
# token indices 28918 appended
# token indices 28919 appended
# token indices 28920 appended
# token indices 28921 appended
# token indices 28922 appended
# token indices 28923 appended
# token indices 28924 appended
# token indices 28925 appended
# token indices 28926 appended
# token indices 28927 appended
# token indices 28928 appended
# token indices 28929 appended
# token indices 28930 appended
# token indices 28931 appended
# token indices 28932 appended
# token indices 28933 appended
# token indices 28934 appended
# token indices 28935 appended
# token indices 28936 appended
# token indices 28937 appended
# token indices 28938 appended
# token indices 28939 appended
# token indices 28940 appended
# token indices 28941 appended
# token indices 28942 appended
# token indices 28943 appended
# token indices 28944 appended
# token indices 28945 appended
# token indices 28946 appended
# token indices 28947 appended
# token indices 28948 appended
# token indices 28949 appended
# token indices 28950 appended
# token indices 28951 appended
# token indices 28952 appended
# token indices 28953 appended
# token indices 28954 appended
# token indices 28955 appended
# token indices 28956 appended
# token indices 28957 appended
# token indices 28958 appended
# token indices 28959 appended
# token indices 28960 appended
# token indices 28961 appended
# token indices 28962 appended
# token indices 28963 appended
# token indices 28964 appended
# token indices 28965 appended
# token indices 28966 appended
# token indices 28967 appended
# token indices 28968 appended
# token indices 28969 appended
# token indices 28970 appended
# token indices 28971 appended
# token indices 28972 appended
# token indices 28973 appended
# token indices 28974 appended
# token indices 28975 appended
# token indices 28976 appended
# token indices 28977 appended
# token indices 28978 appended
# token indices 28979 appended
# token indices 28980 appended
# token indices 28981 appended
# token indices 28982 appended
# token indices 28983 appended
# token indices 28984 appended
# token indices 28985 appended
# token indices 28986 appended
# token indices 28987 appended
# token indices 28988 appended
# token indices 28989 appended
# token indices 28990 appended
# token indices 28991 appended
# token indices 28992 appended
# token indices 28993 appended
# token indices 28994 appended
# token indices 28995 appended
# token indices 28996 appended
# token indices 28997 appended
# token indices 28998 appended
# token indices 28999 appended
# token indices 29000 appended
# token indices 29001 appended
# token indices 29002 appended
# token indices 29003 appended
# token indices 29004 appended
# token indices 29005 appended
# token indices 29006 appended
# token indices 29007 appended
# token indices 29008 appended
# token indices 29009 appended
# token indices 29010 appended
# token indices 29011 appended
# token indices 29012 appended
# token indices 29013 appended
# token indices 29014 appended
# token indices 29015 appended
# token indices 29016 appended
# token indices 29017 appended
# token indices 29018 appended
# token indices 29019 appended
# token indices 29020 appended
# token indices 29021 appended
# token indices 29022 appended
# token indices 29023 appended
# token indices 29024 appended
# token indices 29025 appended
# token indices 29026 appended
# token indices 29027 appended
# token indices 29028 appended
# token indices 29029 appended
# token indices 29030 appended
# token indices 29031 appended
# token indices 29032 appended
# token indices 29033 appended
# token indices 29034 appended
# token indices 29035 appended
# token indices 29036 appended
# token indices 29037 appended
# token indices 29038 appended
# token indices 29039 appended
# token indices 29040 appended
# token indices 29041 appended
# token indices 29042 appended
# token indices 29043 appended
# token indices 29044 appended
# token indices 29045 appended
# token indices 29046 appended
# token indices 29047 appended
# token indices 29048 appended
# token indices 29049 appended
# token indices 29050 appended
# token indices 29051 appended
# token indices 29052 appended
# token indices 29053 appended
# token indices 29054 appended
# token indices 29055 appended
# token indices 29056 appended
# token indices 29057 appended
# token indices 29058 appended
# token indices 29059 appended
# token indices 29060 appended
# token indices 29061 appended
# token indices 29062 appended
# token indices 29063 appended
# token indices 29064 appended
# token indices 29065 appended
# token indices 29066 appended
# token indices 29067 appended
# token indices 29068 appended
# token indices 29069 appended
# token indices 29070 appended
# token indices 29071 appended
# token indices 29072 appended
# token indices 29073 appended
# token indices 29074 appended
# token indices 29075 appended
# token indices 29076 appended
# token indices 29077 appended
# token indices 29078 appended
# token indices 29079 appended
# token indices 29080 appended
# token indices 29081 appended
# token indices 29082 appended
# token indices 29083 appended
# token indices 29084 appended
# token indices 29085 appended
# token indices 29086 appended
# token indices 29087 appended
# token indices 29088 appended
# token indices 29089 appended
# token indices 29090 appended
# token indices 29091 appended
# token indices 29092 appended
# token indices 29093 appended
# token indices 29094 appended
# token indices 29095 appended
# token indices 29096 appended
# token indices 29097 appended
# token indices 29098 appended
# token indices 29099 appended
# token indices 29100 appended
# token indices 29101 appended
# token indices 29102 appended
# token indices 29103 appended
# token indices 29104 appended
# token indices 29105 appended
# token indices 29106 appended
# token indices 29107 appended
# token indices 29108 appended
# token indices 29109 appended
# token indices 29110 appended
# token indices 29111 appended
# token indices 29112 appended
# token indices 29113 appended
# token indices 29114 appended
# token indices 29115 appended
# token indices 29116 appended
# token indices 29117 appended
# token indices 29118 appended
# token indices 29119 appended
# token indices 29120 appended
# token indices 29121 appended
# token indices 29122 appended
# token indices 29123 appended
# token indices 29124 appended
# token indices 29125 appended
# token indices 29126 appended
# token indices 29127 appended
# token indices 29128 appended
# token indices 29129 appended
# token indices 29130 appended
# token indices 29131 appended
# token indices 29132 appended
# token indices 29133 appended
# token indices 29134 appended
# token indices 29135 appended
# token indices 29136 appended
# token indices 29137 appended
# token indices 29138 appended
# token indices 29139 appended
# token indices 29140 appended
# token indices 29141 appended
# Average length of essays: 199.93377710678013
# Minimum length of essays: 3
# Maximum length of essays: 50
# Tensor representation of the first essay:
# [ 245   69   79  331  192  256  821  611   75  654  189   86   51 5286
#   209  406  108  423  351  427  245   69 1545   95  654  124  965  693
#   535  754 1748  613  157  160  299  102    0  507  654  635  571 5294
#    94  209  232  410  597   65  245   69]

# %% [markdown]
# In these tensors the missing word is represented with 0, padding is -1, unknown word (\<UNK>) is 490, and the other words are the representation indexes according to vocabulary. In the experiments we will have 50 150 and 500 word length essays.
